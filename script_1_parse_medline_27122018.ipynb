# %%
from Bio import Medline
import pandas as pd
from affiliation_parser import parse_affil

# %%
with open("table1.csv", "w") as file: #extrai info do medline e faz uma tabela com as seguintes colunas: journal, title, authors, country, year
    with open("sp_nov_2001_2018_pubmed.medline") as handle:
        records = Medline.parse(handle)
        for record in records:
            title = record["TI"]
            journal = record["JT"]
            authors = str(record.get("FAU")).replace(',', '')
            affiliations = str(record.get("AD")) #se fazer um split, perde vários países
            country_first_author = parse_affil(affiliations)["country"] 
            year = record["DP"].split(" ")[0]
            try:
                abstract = record["AB"]
            except:
                abstract = "no abstract"
            file.write(journal + "\t" + title + "\t" + authors + "\t" + country_first_author + "\t" 
                       + year + "\t" + abstract + "\n")

# %%
df = pd.read_csv("table1.csv", sep="\t")
df.columns = ["Journal", "Title", "Authors", "First author country", "Year", "Abstract"]
df
# Out:
#                                                 Journal  \
# 0     International journal of systematic and evolut...
# 1     International journal of systematic and evolut...
# 2     International journal of systematic and evolut...
# 3     International journal of systematic and evolut...
# 4     International journal of systematic and evolut...
# 5                   Systematic and applied microbiology
# 6                   Systematic and applied microbiology
# 7     International journal of systematic and evolut...
# 8     International journal of systematic and evolut...
# 9                Applied and environmental microbiology
# 10                                    Microbial ecology
# 11                                              Heliyon
# 12    International journal of systematic and evolut...
# 13                  Systematic and applied microbiology
# 14                                 Current microbiology
# 15                             Archives of microbiology
# 16    International journal of systematic and evolut...
# 17    International journal of systematic and evolut...
# 18    International journal of systematic and evolut...
# 19                             Archives of microbiology
# 20                  Systematic and applied microbiology
# 21    International journal of systematic and evolut...
# 22    International journal of systematic and evolut...
# 23               Journal of microbiology (Seoul, Korea)
# 24                            Frontiers in microbiology
# 25    International journal of systematic and evolut...
# 26    International journal of systematic and evolut...
# 27    International journal of systematic and evolut...
# 28                                 Current microbiology
# 29                                 Current microbiology
# ...                                                 ...
# 9739  International journal of systematic and evolut...
# 9740  International journal of systematic and evolut...
# 9741  International journal of systematic and evolut...
# 9742  International journal of systematic and evolut...
# 9743  International journal of systematic and evolut...
# 9744  International journal of systematic and evolut...
# 9745  International journal of systematic and evolut...
# 9746  International journal of systematic and evolut...
# 9747  International journal of systematic and evolut...
# 9748  International journal of systematic and evolut...
# 9749                    Microbiology (Reading, England)
# 9750                   Journal of clinical microbiology
# 9751  International journal of systematic and evolut...
# 9752  International journal of systematic and evolut...
# 9753  International journal of systematic and evolut...
# 9754  International journal of systematic and evolut...
# 9755  International journal of systematic and evolut...
# 9756  International journal of systematic and evolut...
# 9757  International journal of systematic and evolut...
# 9758  International journal of systematic and evolut...
# 9759  International journal of systematic and evolut...
# 9760  International journal of systematic and evolut...
# 9761  International journal of systematic and evolut...
# 9762  International journal of systematic and evolut...
# 9763  International journal of systematic and evolut...
# 9764  International journal of systematic and evolut...
# 9765  International journal of systematic and evolut...
# 9766  International journal of systematic and evolut...
# 9767  International journal of systematic and evolut...
# 9768                    Journal of applied microbiology
#
#                                                   Title  \
# 0     Reichenbachiella versicolor sp. nov., isolated...
# 1     Lactobacillus paragasseri sp. nov., a sister t...
# 2     Geobacillus yumthangensis sp. nov., a thermoph...
# 3     Chryseolinea flava sp. nov., a new species of ...
# 4     Ottowia konkukae sp. nov., isolated from rotte...
# 5     Caulobacter zeae sp. nov. and Caulobacter radi...
# 6     Physiological and genomic properties of Thermu...
# 7     Blastococcus litoris sp. nov., isolated from s...
# 8     Mycobacterium decipiens sp. nov., a new specie...
# 9     Genome analysis, metabolic potential and preda...
# 10    A New Species of the gamma-Proteobacterium Fra...
# 11    Diversity of bacteria associated with corn roo...
# 12    Sphingomonas turrisvirgatae sp. nov., an agar-...
# 13    Genome sequences and description of novel exop...
# 14    Biological Synthesis of Ginsenoside Rd Using P...
# 15    Rhodobacter alkalitolerans sp. nov., isolated ...
# 16    Winogradskyella aurantiaca sp. nov., isolated ...
# 17    Sphingobacterium haloxyli sp. nov., an endophy...
# 18    Roseomonas globiformis sp. nov., an airborne b...
# 19    Bhargavaea changchunensis sp. nov. isolated fr...
# 20    Genomic insights into Candidatus Amarolinea aa...
# 21    Aestuariimicrobium soli sp. nov., isolated fro...
# 22    Acuticoccus kandeliae sp. nov., isolated from ...
# 23    Bacteroides sedimenti sp. nov., isolated from ...
# 24    Phenotypic and Genomic Properties of Brachybac...
# 25     Pontibacter terrae sp. nov., isolated from soil.
# 26    Paenibacillus xerothermodurans sp. nov., an ex...
# 27    Flavobacterium effusum sp. nov., isolated from...
# 28    Confluentibacter flavum sp. nov., Isolated fro...
# 29    Pseudopontivivens aestuariicola gen. nov., sp....
# ...                                                 ...
# 9739  Mycoplasma alligatoris sp. nov., from American...
# 9740  Mycoplasma microti sp. nov., isolated from the...
# 9741  Schineria larvae gen. nov., sp. nov., isolated...
# 9742  Enterococcus villorum sp. nov., an enteroadher...
# 9743  Streptimonospora salina gen. nov., sp. nov., a...
# 9744  Pseudomonas alcaliphila sp. nov., a novel facu...
# 9745  Dethiosulfovibrio russensis sp. nov., Dethosul...
# 9746  Saccharopolyspora flava sp. nov. and Saccharop...
# 9747  Characterization of two novel saccharolytic, a...
# 9748  Proposal of Sphingomonas wittichii sp. nov. fo...
# 9749  Characterization of lactobacilli from Scotch m...
# 9750  Tsukamurella strandjordae sp. nov., a proposed...
# 9751  Ornithinimicrobium humiphilum gen. nov., sp. n...
# 9752  Sphingomonas alaskensis sp. nov., a dominant b...
# 9753  Reclassification of [Pseudomonas] doudoroffii ...
# 9754  Vibrio cyclotrophicus sp. nov., a polycyclic a...
# 9755  Arcanobacterium pluranimalium sp. nov., isolat...
# 9756  Lactobacillus cypricasei sp. nov., isolated fr...
# 9757  Clostridium hiranonis sp. nov., a human intest...
# 9758  Amycolatopsis sacchari sp. nov., a moderately ...
# 9759  Reclassification of Desulfobacterium phenolicu...
# 9760  Azospirillum doebereinerae sp. nov., a nitroge...
# 9761  Herbaspirillum frisingense sp. nov., a new nit...
# 9762  Actinomyces marimammalium sp. nov., from marin...
# 9763  Carboxydobrachium pacificum gen. nov., sp. nov...
# 9764  Desulfosporosinus meridiei sp. nov., a spore-f...
# 9765  Clostridium hungatei sp. nov., a mesophilic, N...
# 9766  Hyphomicrobium chloromethanicum sp. nov. and M...
# 9767  Thioflavicoccus mobilis gen. nov., sp. nov., a...
# 9768  Isolation and characterization of a novel hydr...
#
#                                                 Authors  \
# 0     ['Shi Ming-Jing' 'Wang Chong' 'Liu Zuan-Yan' '...
# 1     ['Tanizawa Yasuhiro' 'Tada Ipputa' 'Kobayashi ...
# 2     ['Najar Ishfaq Nabi' 'Sherpa Mingma Thundu' 'D...
# 3           ['Wang Jing-Jing' 'Chen Qi' 'Li Yue-Zhong']
# 4     ['Yi Kwon Jung' 'Im Wan-Taek' 'Kim Dong-Woon' ...
# 5     ['Gao Jun-Lian' 'Sun Pengbo' 'Sun Xiao-Hong' '...
# 6     ['Zhou En-Min' 'Xian Wen-Dong' 'Jiao Jian-Yu' ...
# 7     ['Lee Dong Wan' 'Lee Hanbyul' 'Kwon Bong-Oh' '...
# 8     ['Brown-Elliott Barbara A' 'Simmer Patricia J'...
# 9     ['Livingstone Paul G' 'Morphew Russell M' 'Coo...
# 10    ['Vallesi Adriana' 'Sjodin Andreas' 'Petrelli ...
# 11    ['Tchagang Caetanie F' 'Xu Renlin' 'Overy Davi...
# 12    ['Thaller Maria Cristina' "D'Andrea Marco Mari...
# 13    ['Skraban Jure' 'Cleenwerck Ilse' 'Vandamme Pe...
# 14                   ['Akter Shahina' 'Huq Md Amdadul']
# 15    ['Gandham Suresh' 'Lodha Tushar' 'Chintalapati...
# 16    ['Song Jaeho' 'Jeon Hyoung Tae' 'Lim Yeonjung'...
# 17    ['Liu Lei' 'Hui Nan' 'Liang Li-Xiong' 'Zhang X...
# 18    ['Fang Xiao-Mei' 'Bai Jing-Lin' 'Zhang De-Wu' ...
# 19    ['Tian Feng-Hua' 'Fan Dong-Yu' 'Zhang Chen' 'J...
# 20    ['Andersen Martin H' 'McIlroy Simon J' 'Nieryc...
# 21    ['Chen Ling-Ling' 'Chen Feng' 'Zhao Hua-Zhu' '...
# 22    ['Yin Qi' 'Liang Jinyou' 'Zhang Lv' 'Ma Ke' 'H...
# 23    ['Ismaeil Mohamed' 'Yoshida Naoko' 'Katayama A...
# 24    ['Tak Euon J' 'Kim Pil S' 'Hyun Dong-Wook' 'Ki...
# 25    ['Kim Dong-Uk' 'Kim Ju-Young' 'Jang Jun Hwee' ...
# 26    ['Kaur Navjot' 'Seuylemezian Arman' 'Patil Pra...
# 27    ['Chen Wen-Ming' 'Su Ching-Ling' 'Kwon Soon-Wo...
# 28    ['Li Yu' 'Hou Xin-Jun' 'Shen Xia' 'Han Shuai-B...
# 29    ['Park Sooyeon' 'Choi Jeehyun' 'Park Ji-Min' '...
# ...                                                 ...
# 9739  ['Brown D R' 'Farley J M' 'Zacher L A' 'Carlto...
# 9740  ['Brown D R' 'Talkington D F' 'Thacker W L' 'B...
# 9741  ['Toth E' 'Kovacs G' 'Schumann P' 'Kovacs A L'...
# 9742  ['Vancanneyt M' 'Snauwaert C' 'Cleenwerck I' '...
# 9743  ['Cui X L' 'Mao P H' 'Zeng M' 'Li W J' 'Zhang ...
# 9744  ['Yumoto I' 'Yamazaki K' 'Hishinuma M' 'Nodasa...
# 9745  ['Surkov A V' 'Dubinina G A' 'Lysenko A M' 'Gl...
# 9746  ['Lu Z' 'Liu Z' 'Wang L' 'Zhang Y' 'Qi W' 'Goo...
# 9747  ['Cann I K' 'Stroot P G' 'Mackie K R' 'White B...
# 9748  ['Yabuuchi E' 'Yamamoto H' 'Terakubo S' 'Okamu...
# 9749        ['Simpson K L' 'Pettersson B' 'Priest F G']
# 9750  ['Kattar M M' 'Cookson B T' 'Carlson L D' 'Sti...
# 9751  ['Groth I' 'Schumann P' 'Weiss N' 'Schuetze B'...
# 9752  ['Vancanneyt M' 'Schut F' 'Snauwaert C' 'Goris...
# 9753       ['Brown G R' 'Sutcliffe I C' 'Cummings S P']
# 9754                       ['Hedlund B P' 'Staley J T']
# 9755  ['Lawson P A' 'Falsen E' 'Foster G' 'Eriksson ...
# 9756  ['Lawson P A' 'Papademas P' 'Wacher C' 'Falsen...
# 9757  ['Kitahara M' 'Takamine F' 'Imamura T' 'Benno Y']
# 9758  ['Goodfellow M' 'Kim S B' 'Minnikin D E' 'Whit...
# 9759  ['Kuever J' 'Konneke M' 'Galushko A' 'Drzyzga O']
# 9760  ['Eckert B' 'Weber O B' 'Kirchhof G' 'Halbritt...
# 9761  ['Kirchhof G' 'Eckert B' 'Stoffels M' 'Baldani...
# 9762  ['Hoyles L' 'Pascual C' 'Falsen E' 'Foster G' ...
# 9763  ['Sokolova T G' 'Gonzalez J M' 'Kostrikina N A...
# 9764  ['Robertson W J' 'Bowman J P' 'Franzmann P D' ...
# 9765  ['Monserrate E' 'Leschine S B' 'Canale-Parola E']
# 9766  ['McDonald I R' 'Doronina N V' 'Trotsenko Y A'...
# 9767                         ['Imhoff J F' 'Pfennig N']
# 9768  ['Engelhardt M A' 'Daly K' 'Swannell R P' 'Hea...
#
#           First author country  Year  \
# 0                        china  2018
# 1                        japan  2018
# 2                        india  2018
# 3                        china  2018
# 4                  south korea  2018
# 5                        china  2018
# 6                        china  2018
# 7                  south korea  2018
# 8                        italy  2018
# 9               united kingdom  2018
# 10                       spain  2018
# 11                      canada  2018
# 12                       italy  2018
# 13                         NaN  2018
# 14                 south korea  2018
# 15                       india  2018
# 16                 south korea  2018
# 17                       china  2018
# 18                       china  2018
# 19                       china  2018
# 20                     denmark  2018
# 21                       china  2018
# 22                       china  2018
# 23                       japan  2018
# 24                 south korea  2018
# 25                 south korea  2018
# 26                       india  2018
# 27                      taiwan  2018
# 28                       china  2018
# 29                 south korea  2018
# ...                        ...   ...
# 9739  united states of america  2001
# 9740  united states of america  2001
# 9741                   hungary  2001
# 9742                   belgium  2001
# 9743                     china  2001
# 9744                     japan  2001
# 9745                    russia  2001
# 9746                     china  2001
# 9747  united states of america  2001
# 9748                     japan  2001
# 9749            united kingdom  2001
# 9750  united states of america  2001
# 9751                   germany  2001
# 9752                   belgium  2001
# 9753            united kingdom  2001
# 9754  united states of america  2001
# 9755            united kingdom  2001
# 9756            united kingdom  2001
# 9757                     japan  2001
# 9758            united kingdom  2001
# 9759                   germany  2001
# 9760                   germany  2001
# 9761                   germany  2001
# 9762            united kingdom  2001
# 9763                    russia  2001
# 9764                 australia  2001
# 9765  united states of america  2001
# 9766            united kingdom  2001
# 9767                   germany  2001
# 9768            united kingdom  2001
#
#                                                Abstract
# 0     A Gram-stain-negative, strictly aerobic, non-f...
# 1     Three strains, JCM 5343(T), JCM 5344 and JCM 1...
# 2     A thermophilic, spore-forming, rod-shaped bact...
# 3     A pale yellow bacterial strain, designated SDU...
# 4     A Gram-negative, aerobic, non-motile, non-spor...
# 5     Four bacterial strains designated 410(T), 441,...
# 6     Two closely related, thermophilic bacteria, de...
# 7     A novel Gram-strain-positive, non-spore-formin...
# 8     Two mycobacterial strains with close similarit...
# 9     Herpetosiphon spp are ubiquitous, chemoheterot...
# 10    The study of the draft genome of an Antarctic ...
# 11    Bacteria associated with corn roots inoculated...
# 12    A yellow pigmented and agar-pitting colony was...
# 13    Strains T5K1 and AV446 isolated from apple cid...
# 14    A Gram-stain positive, aerobic, motile, rod-sh...
# 15    An alkali-tolerant, Gram-stain-negative, motil...
# 16    A Gram-stain-negative, non-flagellated, motile...
# 17    A Gram-stain-negative, non-motile, aerobic, no...
# 18    A novel dark pink pigmented bacterium, designa...
# 19    A Gram-staining-positive, aerobic, rod-shaped ...
# 20    Settleability of particles in activated sludge...
# 21    A Gram-reaction-positive, catalase-positive, n...
# 22    A novel bacterial strain, J103(T), was isolate...
# 23    A Gram-negative, anaerobic, non-motile, non-sp...
# 24    Two strains, VM2412(T) and VR2415(T), were iso...
# 25    A bacterial strain, designated 17SD1-15(T), wa...
# 26    A Gram-stain-positive, motile, endospore-produ...
# 27    A yellowish-orange-coloured bacterial strain, ...
# 28    A Gram-stain-negative, rod-shaped, non-motile,...
# 29    A Gram-stain-negative, non-motile and coccoid,...
# ...                                                 ...
# 9739  Mycoplasmas were isolated from multiple tissue...
# 9740  Mycoplasmas were isolated from the respiratory...
# 9741  Four bacterial strains were isolated from the ...
# 9742  The taxonomic positions of five enteroadherent...
# 9743  Actinomycete strain YIM 90002T (= CCTCC 99003T...
# 9744  Facultatively psychrophilic alkaliphilic strai...
# 9745  Four strains of strictly anaerobic, sulfur- an...
# 9746  The generic position of two aerobic, Gram-posi...
# 9747  Two anaerobic, thermophilic, Gram-positive, no...
# 9748  A polyphasic taxonomic study was performed on ...
# 9749  Sixty-four strains of Lactobacillus were isola...
# 9750  We have isolated a gram-positive, weakly acid-...
# 9751  A Gram-positive bacterium originating from gar...
# 9752  Seven Gram-negative strains, isolated in 1990 ...
# 9753  A bacterium, isolate GB6T, capable of degradin...
# 9754  Strain P-2P44T was isolated from creosote-cont...
# 9755  Two strains of a previously undescribed Arcano...
# 9756  Four strains of a hitherto unknown bacterium i...
# 9757  The Clostridium-like organisms TO-931T and HD-...
# 9758  The taxonomic position of a group of moderatel...
# 9759  A mesophilic, sulfate-reducing bacterium (stra...
# 9760  A new group of nitrogen-fixing Azospirillum sp...
# 9761  The enrichment of nitrogen-fixing bacteria fro...
# 9762  Three strains of a previously undescribed Acti...
# 9763  A new anaerobic, thermophilic, CO-utilizing ma...
# 9764  Eight strains of spore-forming, sulfate-reduci...
# 9765  Two strains of obligately anaerobic, mesophili...
# 9766  Two chloromethane-utilizing facultatively meth...
# 9767  A novel phototrophic purple sulfur bacterium w...
# 9768  AIMS: Characterization of a bacterial isolate ...
#
# [9769 rows x 6 columns]

# %%
df["Authors"] = df["Authors"].apply(lambda x: x.lower()).apply(lambda x: x.replace("['","")).apply(lambda x: x.replace('["',"")).apply(lambda x: x.replace("']","")).apply(lambda x: x.replace('"]',"")).apply(lambda x: x.replace('"',"'")).apply(lambda x: x.split("' '"))

# %%
df[df["First author country"].isna()]
# Out:
#                                                 Journal  \
# 13                  Systematic and applied microbiology
# 1189                          Microbes and environments
# 1251  International journal of systematic and evolut...
# 1264  International journal of systematic and evolut...
# 1415  International journal of systematic and evolut...
# 1671  International journal of systematic and evolut...
# 1702  International journal of systematic and evolut...
# 1834  International journal of systematic and evolut...
# 1858  International journal of systematic and evolut...
# 1974                           Archives of microbiology
# 2074  International journal of systematic and evolut...
# 2120                     Journal of economic entomology
# 2318  International journal of systematic and evolut...
# 2320  International journal of systematic and evolut...
# 2322  International journal of systematic and evolut...
# 2352                               Current microbiology
# 2355  International journal of systematic and evolut...
# 2362      Extremophiles : life under extreme conditions
# 2387  International journal of systematic and evolut...
# 2391  International journal of systematic and evolut...
# 2399  International journal of systematic and evolut...
# 2414  International journal of systematic and evolut...
# 2418  International journal of systematic and evolut...
# 2433  International journal of systematic and evolut...
# 2435  International journal of systematic and evolut...
# 2437  International journal of systematic and evolut...
# 2443  International journal of systematic and evolut...
# 2445  International journal of systematic and evolut...
# 2465  International journal of systematic and evolut...
# 2468  International journal of systematic and evolut...
# ...                                                 ...
# 9383      Extremophiles : life under extreme conditions
# 9445  International journal of systematic and evolut...
# 9446  International journal of systematic and evolut...
# 9450  International journal of systematic and evolut...
# 9451  International journal of systematic and evolut...
# 9483                Systematic and applied microbiology
# 9496  International journal of systematic and evolut...
# 9502  International journal of systematic and evolut...
# 9537  International journal of systematic and evolut...
# 9552  International journal of systematic and evolut...
# 9555  International journal of systematic and evolut...
# 9572  International journal of systematic and evolut...
# 9573  International journal of systematic and evolut...
# 9575  International journal of systematic and evolut...
# 9584  International journal of systematic and evolut...
# 9585  International journal of systematic and evolut...
# 9599  International journal of systematic and evolut...
# 9600  International journal of systematic and evolut...
# 9607  International journal of systematic and evolut...
# 9610  International journal of systematic and evolut...
# 9659                   Journal of clinical microbiology
# 9665  International journal of systematic and evolut...
# 9668  International journal of systematic and evolut...
# 9675  International journal of systematic and evolut...
# 9684  International journal of systematic and evolut...
# 9698  International journal of systematic and evolut...
# 9706  International journal of systematic and evolut...
# 9710  International journal of systematic and evolut...
# 9711  International journal of systematic and evolut...
# 9715  International journal of systematic and evolut...
#
#                                                   Title  \
# 13    Genome sequences and description of novel exop...
# 1189  Streptomyces cameroonensis sp. nov., a Geldana...
# 1251  Campylobacter ornithocola sp. nov., a novel me...
# 1264  Psychromonas aquatilis sp. nov., isolated from...
# 1415  Macrococcus canis sp. nov., a skin bacterium a...
# 1671  Pseudoduganella danionis sp. nov., isolated fr...
# 1702  Sphingobacterium jejuense sp. nov., with ginse...
# 1834  Undibacterium danionis sp. nov. isolated from ...
# 1858  Campylobacter geochelonis sp. nov. isolated fr...
# 1974  Description of Hydrogenophaga laconesensis sp....
# 2074  Tumebacillus lipolyticus sp. nov., isolated fr...
# 2120  Parasaccharibacter apium, gen. nov., sp. nov.,...
# 2318  Marinobacter aromaticivorans sp. nov., a polyc...
# 2320  Multilocus sequence analysis of the genus Kurt...
# 2322  Pedobacter alpinus sp. nov., isolated from a p...
# 2352  Lysobacter chengduensis sp. nov. Isolated from...
# 2355  Alicyclobacillus fodiniaquatilis sp. nov., iso...
# 2362  Halopeptonella vilamensis gen. nov, sp. nov., ...
# 2387  Plantactinospora sonchi sp. nov., an actinobac...
# 2391  Roseomonas oryzicola sp. nov., isolated from t...
# 2399  Streptobacillus notomytis sp. nov., isolated f...
# 2414  Leucobacter zeae sp. nov., isolated from the r...
# 2418  Burkholderia dipogonis sp. nov., isolated from...
# 2433  Cryptosporangium cibodasense sp. nov., isolate...
# 2435  Micromonospora nickelidurans sp. nov., isolate...
# 2437  Spiribacter curvatus sp. nov., a moderately ha...
# 2443  Azospirillum soli sp. nov., a nitrogen-fixing ...
# 2445  Alistipes inops sp. nov. and Coprobacter secun...
# 2465  Sphingomonas fonticola sp. nov., isolated from...
# 2468  Description of Acinetobacter populi sp. nov. i...
# ...                                                 ...
# 9383  Halomonas glaciei sp. nov. isolated from fast ...
# 9445  Rheinheimera baltica gen. nov., sp. nov., a bl...
# 9446  Kineosphaera limosa gen. nov., sp. nov., a nov...
# 9450  Halomonas halocynthiae sp. nov., isolated from...
# 9451  Pseudoalteromonas translucida sp. nov. and Pse...
# 9483  Ruminococcus luti sp. nov., isolated from a hu...
# 9496  Psychrobacter submarinus sp. nov. and Psychrob...
# 9502  Taxonomic dissection of the Streptococcus bovi...
# 9537  Oleiphilaceae fam. nov., to include Oleiphilus...
# 9552  Mitsuokella jalaludinii sp. nov., from the rum...
# 9555  Arthrobacter roseus sp. nov., a psychrophilic ...
# 9572  Stenotrophomonas acidaminiphila sp. nov., a st...
# 9573  Saccharomonospora halophila sp. nov., a novel ...
# 9575  Nocardiopsis halotolerans sp. nov., isolated f...
# 9584  Reclassification of Eubacterium formicigeneran...
# 9585  Paenibacillus chinjuensis sp. nov., a novel ex...
# 9599  Pseudoalteromonas ruthenica sp. nov., isolated...
# 9600  Pseudoalteromonas issachenkonii sp. nov., a ba...
# 9607  Anaerobaculum mobile sp. nov., a novel anaerob...
# 9610  Halomonas alimentaria sp. nov., isolated from ...
# 9659  Description of Mycobacterium heckeshornense sp...
# 9665  Planomicrobium koreense gen. nov., sp. nov., a...
# 9668  Sphingomonas aquatilis sp. nov., Sphingomonas ...
# 9675  Hydrogenobacter subterraneus sp. nov., an extr...
# 9684  Novel nitrogen-fixing acetic acid bacteria, Gl...
# 9698  Comamonas nitrativorans sp. nov., a novel deni...
# 9706  Halomonas marisflavae sp. nov., a halophilic b...
# 9710  Bacillus jeotgali sp. nov., isolated from jeot...
# 9711  Sporosarcina aquimarina sp. nov., a bacterium ...
# 9715                       Shewanella japonica sp. nov.
#
#                                                 Authors First author country  \
# 13    [skraban jure, cleenwerck ilse, vandamme peter...                  NaN
# 1189  [boudjeko thaddee, tchinda romaric armel mouaf...                  NaN
# 1251  [caceres alberto, munoz ivo, iraola gregorio, ...                  NaN
# 1264  [kampfer peter, irgang rute, poblete-morales m...                  NaN
# 1415  [gobeli brawand stefanie, cotting kerstin, gom...                  NaN
# 1671  [kampfer peter, irgang rute, busse hans-jurgen...                  NaN
# 1702  [siddiqi muhammad zubair, muhammad shafi siddi...                  NaN
# 1834  [kampfer peter, irgang rute, busse hans-jurgen...                  NaN
# 1858  [piccirillo alessandra, niero giulia, calleros...                  NaN
# 1974  [mantri soniya, chinthalagiri mohan rao, gundl...                  NaN
# 2074  [prasad r v, bhumika v, anil kumar p, srinivas...                  NaN
# 2120  [corby-harris v, snyder l, meador c a d, naldo...                  NaN
# 2318  [cui zhisong, gao wei, xu guangfei, luan xiao,...                  NaN
# 2320  [fang wei, guo min-wei, ruan zhi-yong, xue han...                  NaN
# 2322           [li ai-hua, liu hong-can, zhou yu-guang]                  NaN
# 2352  [wen caifang, xi lixin, she rong, zhao shan, h...                  NaN
# 2355  [zhang bo, wu yu-fan, song jin-long, huang zho...                  NaN
# 2362  [menes rodolfo javier, viera claudia elizabeth...                  NaN
# 2387  [ma zhaoxu, liu chongxi, fan jianlong, he hair...                  NaN
# 2391  [chung eu jin, yoon hwan sik, kim kyung hyun, ...                  NaN
# 2399  [eisenberg tobias, glaeser stefanie p, ewers c...                  NaN
# 2414  [lai wei-an, lin shih-yao, hameed asif, hsu yi...                  NaN
# 2418  [sheu shih-yi, chen ming-hui, liu wendy y y, a...                  NaN
# 2433  [nurkanto arif, lisdiyanti puspita, hamada mor...                  NaN
# 2435  [lin yan bing, fan miao chun, guo yan qing, di...                  NaN
# 2437  [leon maria jose, rodriguez-olmos angel, sanch...                  NaN
# 2443  [lin shih-yao, hameed asif, liu you-cheng, hsu...                  NaN
# 2445  [shkoporov andrei n, chaplin andrei v, khokhlo...                  NaN
# 2465        [sheu shih-yi, chen yi-ling, chen wen-ming]                  NaN
# 2468  [li yong, chang jupu, guo li-min, wang hai-min...                  NaN
# ...                                                 ...                  ...
# 9383  [reddy g s n, raghavan p u m, sarita n b, prak...                  NaN
# 9445  [brettar ingrid, christen richard, hofle manfr...                  NaN
# 9446  [liu wen-tso, hanada satoshi, marsh terrence l...                  NaN
# 9450  [romanenko l a, schumann p, rohde m, mikhailov...                  NaN
# 9451  [ivanova elena p, sawabe tomoo, lysenko anatol...                  NaN
# 9483  [simmering rainer, taras david, schwiertz andr...                  NaN
# 9496  [romanenko lyudmila a, schumann peter, rohde m...                  NaN
# 9502  [poyart claire, quesne gilles, trieu-cuot patr...                  NaN
# 9537  [golyshin peter n, chernikova tatiana n, abrah...                  NaN
# 9552                      [lan g q, ho y w, abdullah n]                  NaN
# 9555  [reddy g s n, prakash j s s, matsumoto g i, st...                  NaN
# 9572  [assih essokazi a, ouattara aboubakar s, thier...                  NaN
# 9573  [al-zarban sheikha s, al-musallam azza a, abba...                  NaN
# 9575  [al-zarban sheikha s, abbas ibrahim, al-musall...                  NaN
# 9584  [taras david, simmering rainer, collins matthe...                  NaN
# 9585  [yoon jung-hoon, seo weon-taek, shin yong kook...                  NaN
# 9599  [ivanova elena p, sawabe tomoo, lysenko anatol...                  NaN
# 9600  [ivanova elena p, sawabe tomoo, alexeeva yuliy...                  NaN
# 9607                 [menes rodolfo javier, muxi lucia]                  NaN
# 9610  [yoon jung-hoon, lee keun-chul, kho yung hee, ...                  NaN
# 9659  [richter e, niemann s, ruesch-gerdes s, harmse...                  NaN
# 9665  [yoon j h, kang s s, lee k c, lee e s, kho y h...                  NaN
# 9668  [lee j s, shin y k, yoon j h, takeuchi m, pyun...                  NaN
# 9675                  [takai k, komatsu t, horikoshi k]                  NaN
# 9684  [fuentes-ramirez l e, bustillos-cristales r, t...                  NaN
# 9698  [etchebehere c, errazquin m i, dabert p, molet...                  NaN
# 9706  [yoon j h, choi s h, lee k c, kho y h, kang k ...                  NaN
# 9710  [yoon j h, kang s s, lee k c, kho y h, choi s ...                  NaN
# 9711  [yoon j h, lee k c, weiss n, kho y h, kang k h...                  NaN
# 9715  [ivanova e p, sawabe t, gorshkova n m, svetash...                  NaN
#
#       Year                                           Abstract
# 13    2018  Strains T5K1 and AV446 isolated from apple cid...
# 1189  2017  The taxonomy of an actinobacterial strain, des...
# 1251  2017  During a study on the prevalence and diversity...
# 1264  2017  A slightly beige-white pigmented, Gram-stainin...
# 1415  2017  Gram-stain-positive cocci were isolated from m...
# 1671  2016  One beige-pigmented, Gram-staining-negative, r...
# 1702  2016  A Gram-stain-negative, strictly aerobic, non-m...
# 1834  2016  One beige-pigmented, Gram-stain-negative, rod-...
# 1858  2016  During a screening study to determine the pres...
# 1974  2016  A light cream color colony was isolated, using...
# 2074  2015  An aerobic, endospore-forming, alkali-tolerant...
# 2120  2016  The honey bee, Apis mellifera L., is host to a...
# 2318  2016  A rod-shaped, Gram-stain-negative, slightly ha...
# 2320  2015  Four novel bacterial strains belonging to the ...
# 2322  2015  Two Gram-staining-negative, aerobic, non-motil...
# 2352  2016  A novel bacterial strain, designated as CF21(T...
# 2355  2015  Two novel, Gram-stain-variable, moderately the...
# 2362  2016  A Gram-negative, halophilic, heterotrophic, ro...
# 2387  2015  A novel actinobacterium, designated strain NEA...
# 2391  2015  A Gram-stain-negative, coccobacilli-shaped bac...
# 2399  2015  A pleomorphic, Gram-negative, rod-shaped, indo...
# 2414  2015  A novel yellow-pigmented, aerobic, rod-shaped,...
# 2418  2015  Seven strains, ICMP 19430T, ICMP 19429, ICMP 1...
# 2433  2015  A novel actinomycete strain, designated LIPI11...
# 2435  2015  An actinomycete, strain K55T, was isolated fro...
# 2437  2015  A novel pink-pigmented bacterial strain, UAH-S...
# 2443  2015  An aerobic, Gram-stain-negative, rod or spiral...
# 2445  2015  Culture-based study of the faecal microbiome i...
# 2465  2015  A bacterial strain designated TNR-2T was isola...
# 2468  2015  Five Gram-negative, non-motile, rod-shaped bac...
# ...    ...                                                ...
# 9383  2003  Eleven psychrophilic bacteria were isolated fr...
# 9445  2002  A set of taxonomically unique, blue-coloured b...
# 9446  2002  A high-G+C gram-positive, motile, non-spore-fo...
# 9450  2002  The marine bacterium strain KMM 1376T was isol...
# 9451  2002  On the basis of phenotypic and genotypic chara...
# 9483  2002  A strain of an unidentified strictly anoxic, g...
# 9496  2002  Two novel psychrophilic, halophilic, Psychroba...
# 9502  2002  The taxonomic dissection of the Streptococcus ...
# 9537  2002  A bacterial isolate, ME102T, was obtained from...
# 9552  2002  Five strains of phytase-producing, gram-negati...
# 9555  2002  Strain CMS 90rT, a red-pigmented bacterium, wa...
# 9572  2002  Two of several strictly aerobic, mesophilic ba...
# 9573  2002  An actinomycete, strain 8T, was isolated from ...
# 9575  2002  A polyphasic taxonomic study of a halotolerant...
# 9584  2002  Two strains of a gram-positively staining, obl...
# 9585  2002  A novel exopolysaccharide-producing bacterium ...
# 9599  2002  On the basis of phenotypic and genotypic chara...
# 9600  2002  Eleven non-pigmented strains of gram-negative,...
# 9607  2002  A novel anaerobic, moderately thermophilic, pe...
# 9610  2002  A gram-negative, moderately halophilic bacteri...
# 9659  2001                                        no abstract
# 9665  2001  A bacterial strain, JG07T, isolated from the K...
# 9668  2001  The taxonomic status of four strains from seve...
# 9675  2001  A novel extreme thermophile was isolated from ...
# 9684  2001  Diazotrophic bacteria were isolated, in two di...
# 9698  2001  A group of Gram-negative denitrifying bacteria...
# 9706  2001  A halophilic Gram-negative bacterial strain, S...
# 9710  2001  Two Gram-variable, rod-shaped, endospore-formi...
# 9711  2001  A light-orange-coloured, facultatively anaerob...
# 9715  2001  Two strains of agar-digesting bacteria, KMM 32...
#
# [251 rows x 6 columns]

# %% [markdown]
# # Contagem autores

# %%
#plus, contagem dos autores
x = list(df["Authors"])
from itertools import chain
y = list(chain.from_iterable(x))

# %%
from collections import Counter

# %%
frequency_authors = Counter(y)

# %%
for key, count in frequency_authors.items():
    name = key
    print([name, count])
# Out:
# ['shi ming-jing', 7]
# ['wang chong', 4]
# ['liu zuan-yan', 2]
# ['jiang lai-xiang', 2]
# ['du zong-jun', 73]
# ['tanizawa yasuhiro', 2]
# ['tada ipputa', 1]
# ['kobayashi hisami', 3]
# ['endo akihito', 13]
# ['maeno shintaro', 1]
# ['toyoda atsushi', 1]
# ['arita masanori', 2]
# ['nakamura yasukazu', 1]
# ['sakamoto mitsuo', 47]
# ['ohkuma moriya', 67]
# ['tohno masanori', 11]
# ['najar ishfaq nabi', 1]
# ['sherpa mingma thundu', 1]
# ['das sayak', 2]
# ['verma kamalesh', 1]
# ['dubey vikash kumar', 1]
# ['thakur nagendra', 2]
# ['wang jing-jing', 1]
# ['chen qi', 3]
# ['li yue-zhong', 2]
# ['yi kwon jung', 1]
# ['im wan-taek', 147]
# ['kim dong-woon', 4]
# ['kim soo-ki', 5]
# ['gao jun-lian', 14]
# ['sun pengbo', 8]
# ['sun xiao-hong', 1]
# ['tong shuai', 1]
# ['yan hui', 8]
# ['han mei-lin', 1]
# ['mao xiao-jie', 4]
# ['sun jian-guang', 14]
# ['zhou en-min', 37]
# ['xian wen-dong', 9]
# ['jiao jian-yu', 10]
# ['liu lan', 29]
# ['li meng-meng', 2]
# ['ding yi-ping', 2]
# ['yin yi-rui', 17]
# ['zhao jiao', 2]
# ['nimaichand salam', 13]
# ['xiao min', 41]
# ['li wen-jun', 384]
# ['lee dong wan', 25]
# ['lee hanbyul', 5]
# ['kwon bong-oh', 3]
# ['khim jong seong', 5]
# ['yim un hyuk', 5]
# ['kim beom seok', 8]
# ['kim jae-jin', 6]
# ['brown-elliott barbara a', 7]
# ['simmer patricia j', 1]
# ['trovato alberto', 3]
# ['hyle emily p', 1]
# ['droz sara', 3]
# ['buckwalter seanne p', 1]
# ['borroni emanuele', 6]
# ['branda john a', 1]
# ['iana elkina', 1]
# ['mariottini alessandro', 12]
# ['nelson jameelah', 1]
# ['matteelli alberto', 1]
# ['toney nadege c', 1]
# ['scarparo claudio', 2]
# ['de man tom j b', 1]
# ['vasireddy ravikiran', 2]
# ['gandhi rajesh t', 1]
# ['wengenack nancy l', 1]
# ['cirillo daniela m', 4]
# ['wallace richard j', 1]
# ['tortoli enrico', 24]
# ['livingstone paul g', 1]
# ['morphew russell m', 1]
# ['cookson alan r', 1]
# ['whitworth david e', 1]
# ['vallesi adriana', 1]
# ['sjodin andreas', 1]
# ['petrelli dezemona', 1]
# ['luporini pierangelo', 1]
# ['taddei anna rita', 1]
# ['thelaus johanna', 1]
# ['ohrman caroline', 1]
# ['nilsson elin', 1]
# ['di giuseppe graziano', 1]
# ['gutierrez gabriel', 1]
# ['villalobo eduardo', 1]
# ['tchagang caetanie f', 1]
# ['xu renlin', 4]
# ['overy david', 1]
# ['blackwell barbara', 1]
# ['chabot denise', 1]
# ['hubbard keith', 1]
# ['doumbou cyr lezin', 1]
# ['bromfield eden s p', 3]
# ['tambong james t', 5]
# ['thaller maria cristina', 1]
# ["d'andrea marco maria", 1]
# ['marmo pasquale', 1]
# ['civitareale cinzia', 1]
# ['casu francesca', 1]
# ['migliore luciana', 1]
# ['skraban jure', 2]
# ['cleenwerck ilse', 61]
# ['vandamme peter', 108]
# ['fanedl lijana', 2]
# ['trcek janja', 6]
# ['akter shahina', 17]
# ['huq md amdadul', 12]
# ['gandham suresh', 1]
# ['lodha tushar', 2]
# ['chintalapati sasikala', 11]
# ['chintalapati venkata ramana', 10]
# ['song jaeho', 18]
# ['jeon hyoung tae', 3]
# ['lim yeonjung', 2]
# ['joung yochan', 63]
# ['cho jang-cheon', 72]
# ['liu lei', 6]
# ['hui nan', 1]
# ['liang li-xiong', 1]
# ['zhang xiao-xia', 22]
# ['li lu-bin', 1]
# ['sun qi-wu', 1]
# ['fang xiao-mei', 5]
# ['bai jing-lin', 3]
# ['zhang de-wu', 1]
# ['su jing', 12]
# ['zhao li-li', 6]
# ['liu hong-yu', 22]
# ['zhang yu-qin', 112]
# ['yu li-yan', 29]
# ['tian feng-hua', 2]
# ['fan dong-yu', 1]
# ['zhang chen', 3]
# ['jia chuan-wen', 2]
# ['gao wei', 6]
# ['li yu', 8]
# ['li chang-tian', 19]
# ['andersen martin h', 1]
# ['mcilroy simon j', 1]
# ['nierychlo marta', 1]
# ['nielsen per h', 2]
# ['albertsen mads', 1]
# ['chen ling-ling', 2]
# ['chen feng', 3]
# ['zhao hua-zhu', 1]
# ['feng zhao-zhong', 2]
# ['zhang hao', 14]
# ['huang xing', 17]
# ['yin qi', 5]
# ['liang jinyou', 1]
# ['zhang lv', 3]
# ['ma ke', 2]
# ['hu zhang-li', 2]
# ['zhang yu', 6]
# ['xu ying', 20]
# ['ismaeil mohamed', 1]
# ['yoshida naoko', 2]
# ['katayama arata', 4]
# ['tak euon j', 1]
# ['kim pil s', 1]
# ['hyun dong-wook', 36]
# ['kim hyun s', 1]
# ['lee june-young', 17]
# ['kang woorim', 10]
# ['sung hojun', 5]
# ['shin na-ri', 39]
# ['kim min-soo', 55]
# ['whon tae w', 1]
# ['bae jin-woo', 94]
# ['kim dong-uk', 23]
# ['kim ju-young', 3]
# ['jang jun hwee', 3]
# ['kim myung kyum', 92]
# ['kaur navjot', 10]
# ['seuylemezian arman', 2]
# ['patil prashant p', 1]
# ['patil prabhu', 2]
# ['krishnamurti srinivasan', 1]
# ['varelas joseph', 1]
# ['smith david j', 1]
# ['mayilraj shanmugam', 43]
# ['vaishampayan parag', 8]
# ['chen wen-ming', 157]
# ['su ching-ling', 5]
# ['kwon soon-wo', 162]
# ['sheu shih-yi', 113]
# ['hou xin-jun', 3]
# ['shen xia', 7]
# ['han shuai-bo', 10]
# ['ju zhao', 3]
# ['zhao zhe', 12]
# ['yu xiao-yun', 16]
# ['wu min', 80]
# ['sun cong', 30]
# ['park sooyeon', 209]
# ['choi jeehyun', 10]
# ['park ji-min', 53]
# ['yoon jung-hoon', 417]
# ['chaudhary dhiraj kumar', 32]
# ['kim jaisoo', 69]
# ['hu yiyi', 2]
# ['feng yu', 2]
# ['qin jiayuan', 1]
# ['radolfova-krizova lenka', 5]
# ['maixnerova martina', 13]
# ['zhang xiaoxia', 19]
# ['nemec alexandr', 15]
# ['zong zhiyong', 2]
# ['huo yue', 1]
# ['kang jong-pyo', 9]
# ['park jin-kyu', 1]
# ['li jinfeng', 1]
# ['chen ling', 3]
# ['yang deok-chun', 72]
# ['choi seon', 5]
# ['lee ji hee', 18]
# ['kang joo won', 14]
# ['choe han na', 17]
# ['seong chi nam', 68]
# ['yang lan', 3]
# ['muhadesi jiang-baota', 3]
# ['wang meng-meng', 1]
# ['wang bao-jun', 20]
# ['liu shuang-jiang', 45]
# ['jiang cheng-ying', 10]
# ['heo jun', 4]
# ['cho hayoung', 13]
# ['hong seung-beom', 36]
# ['kim jeong-seon', 12]
# ['kim soo-jin', 80]
# ['kralova stanislava', 8]
# ['svec pavel', 21]
# ['busse hans-jurgen', 178]
# ['stankova eva', 6]
# ['vaczi peter', 1]
# ['sedlacek ivo', 29]
# ['cao chengliang', 3]
# ['xu tangyu', 1]
# ['liu jinjuan', 1]
# ['cai xiaorui', 1]
# ['sun yong', 6]
# ['qin sheng', 46]
# ['jiang jihong', 3]
# ['huang ying', 68]
# ['raya adam p', 1]
# ['jaffe david a', 1]
# ['chomel bruno b', 4]
# ['ota marissa s', 1]
# ['tsou peter m', 1]
# ['davis aaron z', 1]
# ['olave-leyva jose ignacio', 1]
# ['galvez-romero guillermo', 1]
# ['stuckey matthew j', 1]
# ['kasten rickie w', 1]
# ['obregon-morales cirani', 1]
# ['arechiga-ceballos nidia', 1]
# ['martinez-martinez flor', 1]
# ['aguilar-setien alvaro', 1]
# ['potter robert f', 1]
# ["d'souza alaric w", 1]
# ['wallace meghan a', 1]
# ['shupe angela', 1]
# ['patel sanket', 1]
# ['gul danish', 1]
# ['kwon jennie h', 1]
# ['beatty wandy', 1]
# ['andleeb saadia', 1]
# ['burnham carey-ann d', 1]
# ['dantas gautam', 1]
# ['ambrosini adriana', 1]
# ["sant'anna fernando hayashi", 2]
# ['heinzmann julia', 1]
# ['de carvalho fernandes gabriela', 1]
# ['bach evelise', 2]
# ['passaglia luciane maria pereira', 2]
# ['chen can', 5]
# ['ye yanghui', 1]
# ['wang ruijun', 6]
# ['zhang yinglao', 1]
# ['wu chen', 5]
# ['debnath sanjit c', 1]
# ['ma zhongjun', 2]
# ['wang jidong', 4]
# ['hwang woon mo', 6]
# ['ko yongseok', 4]
# ['kang keunsoo', 9]
# ['ahn tae-young', 27]
# ['chen liying', 1]
# ['lai qiliang', 105]
# ['mu shan', 3]
# ['sun tianyu', 2]
# ['li yuanyuan', 3]
# ['jiang shanwen', 6]
# ['guo xiaowei', 5]
# ['wang xiangjing', 84]
# ['zhao junwei', 55]
# ['xiang wensheng', 87]
# ['lee yunho', 11]
# ['jeon che ok', 164]
# ['malisorn kingchan', 1]
# ['kanchanasin pawina', 3]
# ['phongsopitanun wongsakorn', 16]
# ['tanasupawat somboon', 86]
# ['sannazzaro a i', 1]
# ['torres tejerizo g', 1]
# ['fontana m f', 1]
# ['cumpa velasquez l m', 1]
# ['hansen l h', 1]
# ['pistorio m', 1]
# ['estrella m j', 1]
# ['choi kang duk', 11]
# ['siddiqi muhammad zubair', 27]
# ['liu qingmei', 8]
# ['muhammad shafi siddiqi', 4]
# ['durrani yasser', 1]
# ['lee soon yeol', 2]
# ['kang myung-suk', 20]
# ['im wan taek', 2]
# ['sakdapetsiri chatsuda', 2]
# ['ngaemthao wipaporn', 12]
# ['suriyachadkun chanwit', 28]
# ['duangmal kannika', 26]
# ['kitpreechavanich vichien', 8]
# ['normand philippe', 3]
# ['nouioui imen', 24]
# ['pujic petar', 1]
# ['fournier pascale', 1]
# ['dubost audrey', 1]
# ['schwob guillaume', 1]
# ['klenk hans-peter', 136]
# ['nguyen agnes', 1]
# ['abrouk danis', 1]
# ['herrera-belaroussi aude', 1]
# ['pothier joel f', 5]
# ['pfluger valentin', 2]
# ['fernandez maria p', 2]
# ['zhu hui', 1]
# ['fu bo', 1]
# ['lu shuailing', 1]
# ['liu hongbo', 1]
# ['liu he', 2]
# ['suksaard paweena', 6]
# ['srisuk nantana', 4]
# ['liu hongming', 4]
# ['ren lei', 1]
# ['lu peng', 5]
# ['sun lina', 1]
# ['zhu guoping', 3]
# ['park hongjae', 2]
# ['park byeonghyeok', 3]
# ['choi in-geol', 3]
# ['chanama suchart', 2]
# ['janphen suphansa', 1]
# ['chanama manee', 2]
# ['ghodhbane-gtari faten', 16]
# ['jando marlen', 3]
# ['tisa louis s', 5]
# ['gtari maher', 17]
# ['dong chunming', 10]
# ['liu renju', 1]
# ['liu yang', 35]
# ['shao zongze', 96]
# ['yuan tao', 1]
# ['liu lihui', 1]
# ['huang shufen', 1]
# ['taher ali hussein', 1]
# ['tan zhiyuan', 5]
# ['wu guojie', 1]
# ['peng guixiang', 5]
# ['ohn jeong-eun', 2]
# ['ten leonid n', 72]
# ['kim byung-oh', 7]
# ['cho young-je', 8]
# ['jung hee-young', 50]
# ['park yu jin', 1]
# ['jeong sang eun', 15]
# ['jung hye su', 4]
# ['park so yoon', 7]
# ['yun bo-ram', 3]
# ['park sunjoo', 1]
# ['kim min-kyeong', 6]
# ['park jisun', 4]
# ['kim seung bum', 72]
# ['dong yingying', 1]
# ['liu yuhui', 4]
# ['chen nanchun', 1]
# ['zhong yijian', 1]
# ['liu li', 2]
# ['xie qinglin', 1]
# ['sultanpuram vishnuvardhan reddy', 13]
# ['mothe thirumala', 12]
# ['liao hu', 3]
# ['li yuqian', 3]
# ['lin xiaolan', 3]
# ['tian yun', 15]
# ['wang dejia', 1]
# ['xiang yangquan', 2]
# ['jiang chengyan', 1]
# ['zhang juan', 3]
# ['hua ziyi', 3]
# ['niu lili', 10]
# ['luo liqiang', 1]
# ['chen hanyi', 2]
# ['han lu', 12]
# ['feng qingqing', 5]
# ['fan qiuming', 1]
# ['lv jie', 20]
# ['chen peizhen', 1]
# ['li shaopeng', 1]
# ['li qing x', 8]
# ['fedi stefano', 1]
# ['cappelletti martina', 1]
# ['sandri federica', 1]
# ['turner raymond j', 1]
# ['zannoni davide', 1]
# ['kim seo-yeong', 1]
# ['lee seung-yeol', 31]
# ['kim seung-han', 1]
# ['kang in-kyu', 15]
# ['zhang weiyan', 1]
# ['yuan ye', 2]
# ['su dengquan', 1]
# ['ding lijian', 1]
# ['yan xiaojun', 1]
# ['epstein slava s', 4]
# ['he shan', 1]
# ['lee boeun', 1]
# ['lee kangseok', 6]
# ['chen wu', 1]
# ['fu ge-yi', 9]
# ['kudryashova ekaterina b', 1]
# ['karlyshev andrey v', 1]
# ['ariskina elena v', 1]
# ['streshinskaya galina m', 2]
# ['vinokurova nataliy g', 1]
# ['kopitsyn dmitry s', 3]
# ['evtushenko lyudmila i', 7]
# ['wong shu-kuan', 3]
# ['yoshizawa susumu', 17]
# ['nakajima yu', 1]
# ['cuadra marie johanna', 1]
# ['nogi yuichi', 38]
# ['nakamura keiji', 1]
# ['takami hideto', 5]
# ['ogura yoshitoshi', 7]
# ['hayashi tetsuya', 7]
# ['chiura hiroshi xavier', 4]
# ['hamasaki koji', 4]
# ['ahn jae-hyung', 51]
# ['weon hang-yeon', 144]
# ['zhao qiannan', 1]
# ['cao tingting', 5]
# ['zhao xueli', 4]
# ['xue han', 11]
# ['piao chun-gen', 15]
# ['wang xi-zhuo', 5]
# ['lin cai-li', 4]
# ['guo min-wei', 11]
# ['li yong', 25]
# ['han ji-ru', 11]
# ['liu chun-li', 1]
# ['li fei-na', 7]
# ['liao shuilin', 2]
# ['guo min', 4]
# ['tuo li', 14]
# ['yan xinyu', 2]
# ['li wenlian', 2]
# ['jin tao', 2]
# ['lee simon ming-yuen', 4]
# ['sun cheng-hang', 18]
# ['kim hyun-joong', 1]
# ['lee hye jin', 1]
# ['lim bora', 1]
# ['kim eiseul', 1]
# ['kim hae-yeong', 1]
# ['suh minhwan', 1]
# ['hur moonsuk', 1]
# ['rhode manfred', 2]
# ['sangal vartul', 5]
# ['song zhi-man', 2]
# ['wu yanhong', 6]
# ['zhang xiao-hua', 59]
# ['yu min', 9]
# ['navarro-torre salvadora', 2]
# ['carro lorena', 26]
# ['rodriguez-llorente ignacio d', 4]
# ['pajuelo eloisa', 3]
# ['caviedes miguel angel', 2]
# ['igual jose mariano', 6]
# ['redondo-gomez susana', 4]
# ['camacho maria', 7]
# ['montero-calasanz maria del carmen', 24]
# ['fall n s', 1]
# ['raoult d', 79]
# ['sokhna c', 8]
# ['lagier j c', 7]
# ['mbogning fonkou m d', 1]
# ['mailhe m', 10]
# ['ndongo s', 9]
# ['ricaboni d', 10]
# ['morand a', 2]
# ['cornu f', 1]
# ['tidjani alou m', 4]
# ['bilen m', 13]
# ['andrieu c', 2]
# ['levasseur a', 3]
# ['cadoret f', 31]
# ['de alvarenga luna viggiano', 1]
# ['vaz marcelo gomes marcal vieira', 1]
# ['genuario diego bonaldo', 2]
# ['esteves-ferreira alberto a', 1]
# ['almeida allan v martins', 1]
# ['de castro naira valle', 1]
# ['lizieri claudineia', 1]
# ['souza jose joao l l', 1]
# ['schaefer carlos ernesto g r', 1]
# ['nunes-nesi adriano', 1]
# ['araujo wagner l', 1]
# ['wang yang', 29]
# ['luo xiao-xia', 12]
# ['xia zhan-feng', 16]
# ['wan chuan-xing', 11]
# ['alim almira', 1]
# ['zhang li-li', 26]
# ['dione niokhor', 1]
# ['bellali sara', 1]
# ['yasir muhammad', 12]
# ['azhar esam i', 1]
# ['bibi fehmida', 13]
# ['beye mamadou', 6]
# ['armstrong nicholas', 15]
# ['cadoret frederic', 6]
# ['jiman-fatani asif a', 1]
# ['helmy nayel', 2]
# ['rathored jaishriram', 5]
# ['labas noemie', 3]
# ['fournier pierre-edouard', 30]
# ['raoult didier', 61]
# ['lagier jean-christophe', 8]
# ['revesz fruzsina', 1]
# ['toth erika m', 19]
# ['kriszt balazs', 5]
# ['boka karoly', 2]
# ['benedek tibor', 4]
# ['sarkany orsolya', 1]
# ['nagy zsuzsa', 1]
# ['tancsics andras', 8]
# ['castro jean franco', 2]
# ['choi seonbin', 1]
# ['yang seung-jo', 9]
# ['kim byung-yong', 78]
# ['trujillo martha e', 38]
# ['riesco raul', 9]
# ['rahmani tara p d', 1]
# ['bull alan t', 18]
# ['sutcliffe iain c', 6]
# ['asenjo juan a', 6]
# ['andrews barbara', 1]
# ['goodfellow michael', 109]
# ['li li', 24]
# ['li yan-qiong', 4]
# ['fu yu-song', 2]
# ['zhang hui', 13]
# ['alkhalifah dalal hussien m', 2]
# ['salam nimaichand', 29]
# ['hozzein wael n', 40]
# ['asem mipeshwaree devi', 9]
# ['braun markus santhosh', 3]
# ['wang erjia', 2]
# ['zimmermann stefan', 3]
# ['wink michael', 4]
# ['ramaprasad e v v', 17]
# ['mahidhara ganesh', 1]
# ['sasikala ch', 93]
# ['ramana ch v', 93]
# ['chen dong-zhi', 1]
# ['yu ning-ning', 1]
# ['chu qi-ying', 1]
# ['chen jing', 3]
# ['ye jie-xu', 1]
# ['cheng zhuo-wei', 1]
# ['zhang shi-han', 1]
# ['chen jian-meng', 1]
# ['xia fan', 8]
# ['ou-yang tian-na', 2]
# ['gao zeng-hong', 3]
# ['qiu li-hong', 16]
# ['de meyer sofie e', 15]
# ['cnockaert margo', 30]
# ['moulin lionel', 5]
# ['howieson john g', 7]
# ['hwang ye-ji', 3]
# ['son jin-soo', 2]
# ['ghim sa-youl', 6]
# ['han young eun', 1]
# ['park kyeung il', 3]
# ['han jeung-sul', 2]
# ['dahal ram hari', 22]
# ['mu yang', 1]
# ['jia wei-bin', 3]
# ['ke zhuang', 1]
# ['zhuang wen', 2]
# ['wang hong-mei', 5]
# ['jiang jian-dong', 16]
# ['chen kai', 12]
# ['chen qing', 13]
# ['wang kai-ling', 2]
# ['liang jin-you', 1]
# ['lu hui-bin', 1]
# ['xing peng', 3]
# ['zhai lei', 10]
# ['phurbu dorji', 2]
# ['tang qian', 2]
# ['wu qing-long', 5]
# ['behera pratiksha', 2]
# ['mahapatra madhusmita', 1]
# ['ramana v venkata', 9]
# ['joseph neetha', 6]
# ['joshi amaraja', 3]
# ['shouche yogesh', 5]
# ['suar mrutyunjay', 6]
# ['pattnaik ajit k', 2]
# ['rastogi gurdeep', 5]
# ['zhou guo-wei', 3]
# ['yang xiao-ru', 3]
# ['su jian-qiang', 2]
# ['zheng bang-xiao', 3]
# ['zhu yong-guan', 2]
# ['jang hye-jin', 1]
# ['park miri', 6]
# ['hu qiang', 3]
# ['zhang long', 9]
# ['hang ping', 1]
# ['zhou xi-yi', 1]
# ['li shun-peng', 46]
# ['wang zhikuan', 3]
# ['jiang binjin', 1]
# ['li xiaoguang', 4]
# ['gan longzhan', 6]
# ['long xiufeng', 8]
# ['zhang yuqin', 9]
# ['tian yongqiang', 10]
# ['khalifa ashraf', 2]
# ['nakasuji yuta', 1]
# ['saka norikuni', 1]
# ['honjo hiroki', 1]
# ['asakawa susumu', 3]
# ['watanabe takeshi', 1]
# ['lee soon youl', 4]
# ['lai xinting', 1]
# ['hou yanyan', 2]
# ['zhang yuqing', 1]
# ['zhou xing-kui', 14]
# ['mi qi-li', 2]
# ['yao jian-hua', 1]
# ['wu heng', 1]
# ['liu xiu-ming', 1]
# ['li yuan-dong', 1]
# ['duan yan-qing', 21]
# ['chen jian-hua', 1]
# ['dang li-zhi', 2]
# ['mo ming-he', 5]
# ['li xue-mei', 2]
# ['arahal david r', 27]
# ['lucena teresa', 19]
# ['rodrigo-torres lidia', 3]
# ['pujalte maria j', 26]
# ['cho ha-young', 1]
# ['fukano hanako', 2]
# ['yoshida mitsunori', 1]
# ['kazumi yuko', 1]
# ['fujiwara nagatoshi', 12]
# ['katayama kinya', 2]
# ['miyamoto yuji', 1]
# ['fujimoto noriki', 2]
# ['hongsheng wang', 1]
# ['mizumoto chisaki', 1]
# ['koizumi yusuke', 1]
# ['maeda hiroyoshi', 1]
# ['hiranuma osamu', 1]
# ['mitarai satoshi', 1]
# ['ishii norihisa', 2]
# ['hoshino yoshihiko', 3]
# ['margesin rosa', 35]
# ['albuquerque luciana', 29]
# ['zhang de-chao', 50]
# ['froufe hugo j c', 3]
# ['severino rita', 1]
# ['roxo ines', 1]
# ['egas conceicao', 3]
# ['da costa milton s', 54]
# ['wu bo', 3]
# ['zhao shuai', 2]
# ['yuan bo', 9]
# ['hahn martin w', 16]
# ['koll ulrike', 7]
# ['schmidt johanna', 9]
# ['huymann lesley r', 2]
# ['karbon gerlinde', 3]
# ['lang elke', 30]
# ['singleton david r', 3]
# ['lee janice', 1]
# ['dickey allison n', 1]
# ['stroud aaron', 1]
# ['scholl elizabeth h', 1]
# ['wright fred a', 1]
# ['aitken michael d', 7]
# ['baek kiwoon', 18]
# ['chung eu jin', 20]
# ['choi gang-guk', 2]
# ['kim min-kyu', 4]
# ['lim sangyong', 18]
# ['choi ahyoung', 22]
# ['liu shi-qi', 1]
# ['sun qing-lei', 3]
# ['sun yuan-yuan', 1]
# ['yu chao', 7]
# ['sun li', 7]
# ['kampfer peter', 209]
# ['glaeser stefanie p', 99]
# ['packroff gabriele', 1]
# ['behringer katja', 1]
# ['exner martin', 1]
# ['chakraborty trinad', 3]
# ['schmithausen ricarda m', 1]
# ['doijad swapnil', 3]
# ['diop khoudia', 6]
# ['diop awa', 5]
# ['michelle caroline', 8]
# ['richez magali', 3]
# ['bretelle florence', 6]
# ['fenollar florence', 6]
# ['wei yuli', 2]
# ['mao haiyan', 1]
# ['xu yunping', 2]
# ['zou wencai', 1]
# ['fang jiasong', 3]
# ['blom jochen', 5]
# ['zhang qi', 5]
# ['kanjanasuntree rungravee', 3]
# ['kim jong-hwa', 23]
# ['sukhoom ampaitip', 7]
# ['kantachote duangporn', 4]
# ['kim wonyong', 54]
# ['zhang ling-yu', 3]
# ['ming hong', 42]
# ['zhao zhuo-li', 5]
# ['ji wei-li', 4]
# ['fang bao-zhu', 12]
# ['nie guo-xing', 30]
# ['wei yahong', 2]
# ['wang baodan', 1]
# ['zhang limei', 1]
# ['zhang jianguo', 1]
# ['chen shaolin', 1]
# ['kim jae-heon', 1]
# ['founkou m d mbogning', 1]
# ['dubourg g', 17]
# ['daoud z', 10]
# ['guu jia-rong', 1]
# ['wang li-ting', 6]
# ['hamada moriyuki', 59]
# ['wang chihuei', 1]
# ['lin ru-wei', 1]
# ['huang lina', 1]
# ['watanabe koichi', 11]
# ['kim su jeong', 2]
# ['kim min ji', 1]
# ['lee ju yeon', 1]
# ['lee yoon seo', 1]
# ['zhang jing', 16]
# ['slobodkina g b', 10]
# ['baslerov r v', 5]
# ['kostryukova n k', 1]
# ['bonch-osmolovskaya e a', 27]
# ['slobodkin a i', 14]
# ['bouam a', 1]
# ['armstrong n', 5]
# ['drancourt m', 2]
# ['soto esteban', 1]
# ['griffin matt j', 1]
# ['morales juan alberto', 1]
# ['calvo elias barquero', 1]
# ['de alexandre sebastiao fernanda', 1]
# ['porras adrian lopez', 1]
# ['viquez-rodriguez xindy', 1]
# ['reichley stephen r', 1]
# ['rosser thomas g', 1]
# ['ware cynthia', 1]
# ['byrne barbara a', 1]
# ['garcia julio c', 1]
# ['lafrentz benjamin r', 1]
# ['camus alvin c', 2]
# ['lee soon dong', 72]
# ['bilen melhem', 3]
# ['fonkou maxime descartes mbogning', 1]
# ['tomei enora', 1]
# ['bittar fadi', 7]
# ['daoud ziad', 2]
# ['mbogning fonkou maxime descartes', 1]
# ['khelaifia saber', 10]
# ['nguyen thi tien', 2]
# ['delerce jeremy', 5]
# ['kang heeyoung', 29]
# ['cha inseong', 3]
# ['kim haneul', 40]
# ['joh kiseong', 45]
# ['bernard kathryn', 3]
# ['burdz tamara', 2]
# ['wiebe deborah', 2]
# ['alfa michelle', 1]
# ['bernier anne-marie', 1]
# ['lee jung-sook', 129]
# ['oh tae-kwnag', 1]
# ['machado ricardo a r', 1]
# ['wuthrich daniel', 1]
# ['kuhnert peter', 8]
# ['arce carla c m', 1]
# ['thonen lisa', 1]
# ['ruiz celia', 1]
# ['zhang xi', 1]
# ['robert christelle a m', 1]
# ['karimi javad', 1]
# ['kamali shokoofeh', 1]
# ['ma juan', 1]
# ['bruggmann remy', 1]
# ['erb matthias', 1]
# ['lim soo jeong', 1]
# ['mohammadipanah fatemeh', 8]
# ['atasayar ewelina', 5]
# ['heidarian sheida', 1]
# ['wink joachim', 11]
# ['wang jian', 14]
# ['leiva sergio', 1]
# ['huang jiao', 1]
# ['balusamy sri renukadevi', 1]
# ['natarajan sathishkumar', 1]
# ['yoon jae-hyun', 1]
# ['lee sun-young', 2]
# ['saati-santamaria zaki', 1]
# ['lopez-mondejar ruben', 1]
# ['jimenez-gomez alejandro', 1]
# ['diez-mendez alexandra', 2]
# ['vetrovsky tomas', 1]
# ['igual jose m', 20]
# ['velazquez encarna', 70]
# ['kolarik miroslav', 3]
# ['rivas raul', 39]
# ['garcia-fraile paula', 13]
# ['takeshita kazutaka', 1]
# ['tamaki hideyuki', 17]
# ['ohbayashi tsubasa', 1]
# ['meng xian-ying', 6]
# ['sone teruo', 4]
# ['mitani yasuo', 1]
# ['peeters charlotte', 7]
# ['kikuchi yoshitomo', 1]
# ['jang jun hyeong', 8]
# ['lee dongwook', 8]
# ['seo taegun', 14]
# ['liang qi-yun', 3]
# ['xu zhen-xing', 8]
# ['chen guan-jun', 54]
# ['cole jessica k', 4]
# ['morton beau r', 2]
# ['cardamone hayley c', 2]
# ['lake hannah r r', 2]
# ['dohnalkova alice c', 4]
# ['kim young-mo', 2]
# ['kyle jennifer e', 2]
# ['maezato yukari', 2]
# ['dana karl l', 2]
# ['metz thomas o', 2]
# ['romine margaret f', 2]
# ['nelson william c', 2]
# ['lindemann stephen r', 2]
# ['lu fengjuan', 1]
# ['zhang heming', 4]
# ['tian jiewei', 5]
# ['he linling', 1]
# ['chu yiwen', 2]
# ['shin su-kyoung', 9]
# ['kim eunji', 9]
# ['yi hana', 38]
# ['wang haisheng', 3]
# ['wang shuangyan', 1]
# ['zhao baisuo', 7]
# ['lou kai', 20]
# ['xing xin-hui', 1]
# ['wang jianming', 1]
# ['zhang qiaoyan', 1]
# ['qin song', 1]
# ['luo xiaoxia', 3]
# ['kim seol-hee', 1]
# ['kim jong-geol', 11]
# ['jung man-young', 10]
# ['kim so-jeong', 20]
# ['gwak joo-han', 3]
# ['yu woon-jong', 1]
# ['roh seong woon', 72]
# ['kim yang-hoon', 1]
# ['rhee sung-keun', 31]
# ['labella alejandro m', 2]
# ['castro m dolores', 1]
# ['manchado manuel', 2]
# ['borrego juan j', 2]
# ['chen wei-ting', 2]
# ['young chiu-chung', 134]
# ['ma hui', 1]
# ['ren hao', 1]
# ['huang lingfeng', 1]
# ['luo yuanrong', 1]
# ['amoozegar mohammad ali', 28]
# ['shahinpei azadeh', 6]
# ['makzum somaye', 1]
# ['rafieyan shokufeh', 1]
# ['moshtaghi nikou mahdi', 5]
# ['sproer cathrin', 143]
# ['ventosa antonio', 68]
# ['ren mengnan', 1]
# ['li xiaoyan', 1]
# ['zhang yueqi', 1]
# ['jin yu', 1]
# ['li siqi', 1]
# ['huang haidong', 1]
# ['zhuang lingping', 2]
# ['lin binbin', 1]
# ['qin fei', 1]
# ['luo lianzhong', 1]
# ['wang xiao-qun', 3]
# ['li chang-ming', 4]
# ['dunlap christopher a', 15]
# ['rooney alejandro p', 21]
# ['huang cheng-wen', 5]
# ['chen jhen-ci', 9]
# ['chen zih-han', 8]
# ['lv ying-ying', 11]
# ['zhang xian-jiao', 1]
# ['li an-zhang', 6]
# ['zou wei-ling', 1]
# ['feng guang-da', 12]
# ['zhu hong-hui', 21]
# ['luedin samuel m', 1]
# ['danza francesco', 1]
# ['storelli nicola', 2]
# ['frigaard niels-ulrik', 1]
# ['wittwer matthias', 1]
# ['tonolla mauro', 4]
# ['lim soo-jeong', 1]
# ['yu zhiliang', 2]
# ['cao yang', 1]
# ['zhou guoqiang', 1]
# ['yin jianhua', 1]
# ['qiu juanping', 1]
# ['rong cu-huang', 1]
# ['hao ling-yun', 1]
# ['lai qi-liang', 4]
# ['li shuang-fei', 1]
# ['won sung-min', 34]
# ['mori koji', 15]
# ['yamaguchi kaoru', 3]
# ['hanada satoshi', 44]
# ['furmanczyk ewa m', 2]
# ['kaminski michal a', 2]
# ['lipinski leszek', 2]
# ['dziembowski andrzej', 2]
# ['sobczak adam', 2]
# ['lu huibin', 1]
# ['wu qinglong', 1]
# ['jin decai', 4]
# ['kong xiao', 3]
# ['wang jie', 1]
# ['sun jiajun', 1]
# ['yu xiangyang', 2]
# ['zhuang xuliang', 3]
# ['deng ye', 3]
# ['bai zhihui', 4]
# ['saha tilak', 1]
# ['chakraborty biswanath', 1]
# ['chakraborty ranadhir', 3]
# ['iino takao', 21]
# ['yuki masahiro', 2]
# ['robert catherine', 14]
# ['pinto fabrizio di', 1]
# ['lopez maria m', 3]
# ['lopez-soriano pablo', 1]
# ['garita-cambronero jerson', 1]
# ['beltran carmen', 1]
# ['taghouti geraldine', 1]
# ['portier perrine', 2]
# ['cubero jaime', 1]
# ['fischer-le saux marion', 5]
# ['marco-noales ester', 3]
# ['zhai jing-yu', 2]
# ['zhang chong-ya', 7]
# ['shi jie-ying', 1]
# ['ding lin-xian', 5]
# ['hsieh tsai-ying', 4]
# ['kim hyun sik', 12]
# ['kim pil soo', 24]
# ['tak euon jung', 7]
# ['jung mi-ja', 31]
# ['yun ji-hyun', 17]
# ['whon tae woong', 29]
# ['rho jeong rae', 2]
# ['park sun duk', 4]
# ['shim hyung eun', 4]
# ['jin mei-fang', 1]
# ['quan xiao-tian', 1]
# ['liu qing-zhen', 1]
# ['yu hong-shan', 5]
# ['lee hyosun', 18]
# ['ka jong-ok', 26]
# ['kristyanto sylvia', 4]
# ['nguyen tuan manh', 13]
# ['lee sang-seob', 42]
# ['lee jae-won', 1]
# ['kim ye-eun', 1]
# ['park soo-je', 18]
# ['niu lina', 5]
# ['hu shoukui', 7]
# ['lu shan', 11]
# ['lai xin-he', 6]
# ['yang jing', 9]
# ['jin dong', 11]
# ['rao langyu', 1]
# ['lu gang', 2]
# ['xu jianguo', 11]
# ['feng tingye', 3]
# ['kim kyung hyun', 16]
# ['chun byung hee', 6]
# ['beye m', 3]
# ['bakour s', 1]
# ['le dault e', 1]
# ['rathored j', 11]
# ['michelle c', 11]
# ['fournier p-e', 48]
# ['seck e h', 2]
# ['diop a', 2]
# ['delerce j', 7]
# ['khelaifia s', 17]
# ['mogany trisha', 1]
# ['swalaha feroz m', 1]
# ['allam mushal', 1]
# ['mtshali phillip senzo', 1]
# ['ismail arshad', 1]
# ['kumari sheena', 1]
# ['bux faizal', 1]
# ['yoon jaewoo', 53]
# ['kang dong-hee', 1]
# ['yu xiao-dong', 1]
# ['khieu thi-nhan', 7]
# ['chu-ky son', 1]
# ['cheng li-jiao', 1]
# ['meng xiao-lin', 8]
# ['lin pei', 15]
# ['yan zheng-fei', 24]
# ['yi tae-hoo', 86]
# ['murra may', 1]
# ['lutzen lisbeth', 1]
# ['barut aynur', 1]
# ['zbinden reinhard', 3]
# ['lund marianne', 1]
# ['villesen palle', 1]
# ['norskov-lauritsen niels', 2]
# ['xi lijun', 12]
# ['qiao nenghu', 4]
# ['liu dejian', 3]
# ['li jing', 11]
# ['zhang jingjing', 3]
# ['liu jianguo', 3]
# ['ndiaye c', 1]
# ['bassene h', 2]
# ['bittar f', 6]
# ['robert c', 5]
# ['di pinto f', 5]
# ['lagier j-c', 21]
# ['xu bingxue', 1]
# ['hu beiyu', 1]
# ['lan ying', 1]
# ['zhu yaxin', 1]
# ['dai xin', 17]
# ['huang li', 3]
# ['du wenbin', 1]
# ['goldberg stacey r', 1]
# ['haltli brad a', 1]
# ['correa hebelin', 1]
# ['kerr russell g', 3]
# ['pitt alexandra', 3]
# ['whitman william b', 24]
# ['woyke tanja', 8]
# ['wang nan-nan', 3]
# ['li ying-xiu', 2]
# ['kook moochang', 45]
# ['gao yuhang', 2]
# ['piao chenyu', 7]
# ['wang han', 5]
# ['shi linlin', 4]
# ['song jia', 4]
# ['zhang junjie', 1]
# ['guo chen', 1]
# ['chen wenfeng', 1]
# ['de lajudie philippe', 3]
# ['zhang zhiyan', 1]
# ['shang yimin', 1]
# ['wang en tao', 44]
# ['yu yang-huan', 1]
# ['zhang ran', 2]
# ['ma xin-yuan', 1]
# ['zhong shu-fen', 1]
# ['lu zu-er', 1]
# ['xiao sen-yang', 1]
# ['meng yu-chen', 3]
# ['liu hong-can', 62]
# ['zhou yu-guang', 64]
# ['cai man', 18]
# ['kang yingqian', 1]
# ['wadaan mohammed a m', 11]
# ['lu lu-yao', 1]
# ['xing zi-yu', 1]
# ['hu ting', 1]
# ['lu jia-sen', 1]
# ['castro david j', 2]
# ['cerezo isabel', 1]
# ['sampedro inmaculada', 1]
# ['martinez-checa fernando', 16]
# ['akter sumi', 1]
# ['shin mann kyoon', 1]
# ['wang feng-qing', 7]
# ['ren li-hua', 1]
# ['zou rong-jie', 1]
# ['sun yu-zeng', 1]
# ['liu xiao-jing', 1]
# ['jiang fang', 1]
# ['liu li-juan', 1]
# ['ahnia hadjira', 1]
# ['bourebaba yasmina', 1]
# ['duran david', 3]
# ['boulila farida', 1]
# ['palacios jose m', 1]
# ['rey luis', 3]
# ['ruiz-argueso tomas', 3]
# ['boulila abdelghani', 1]
# ['imperial juan', 3]
# ["o'hara-hanley kory", 1]
# ['harrison alisha', 1]
# ['soby scott d', 2]
# ['mcfrederick quinn s', 2]
# ['vuong hoang q', 1]
# ['rothman jason a', 1]
# ['mo ping', 1]
# ['zhao jiarong', 1]
# ['li kaiqin', 1]
# ['tang xinke', 1]
# ['gao jian', 2]
# ['weber mareike', 1]
# ['schunemann wiebke', 1]
# ['fuss janina', 1]
# ['lipski andre', 14]
# ['cai haiyuan', 7]
# ['he weihong', 2]
# ['yanan wang', 1]
# ['yan zaisheng', 2]
# ['wang changhui', 1]
# ['xu huacheng', 2]
# ['shao keqiang', 1]
# ['ludvigsen jane', 1]
# ['porcellato davide', 1]
# ['amdam gro v', 1]
# ['rudi knut', 1]
# ['gilbert maarten j', 3]
# ['zomer aldert l', 1]
# ['timmerman arjen j', 2]
# ['spaninks mirlin p', 1]
# ['rubio-garcia ana', 1]
# ['rossen john w', 1]
# ['duim birgitta', 3]
# ['wagenaar jaap a', 3]
# ['take akira', 7]
# ['inahashi yuki', 20]
# ['omura satoshi', 36]
# ['takahashi yoko', 58]
# ['matsumoto atsuko', 51]
# ['ko dong-jin', 1]
# ['kim ji-sun', 2]
# ['park doo-sang', 27]
# ['lee dae-hee', 1]
# ['heo sun-yeon', 1]
# ['seo jeong-woo', 2]
# ['kim chul ho', 2]
# ['oh baek-rock', 1]
# ['jo jung hun', 4]
# ['chun se yoon', 1]
# ['choi gyu-min', 9]
# ['kim sang young', 1]
# ['tang lili', 4]
# ['zhang zenghu', 16]
# ['zhou chao', 1]
# ['cui rong', 1]
# ['tian yu', 1]
# ['zhang yongyu', 4]
# ['trachsel julian', 1]
# ['humphrey samuel', 1]
# ['allen heather k', 1]
# ['xu lin', 20]
# ['sun jingjing', 1]
# ['wang wei', 13]
# ['ying yu', 2]
# ['zhu xiangjie', 1]
# ['liu junzhong', 1]
# ['hao jianhua', 1]
# ['park a-young', 4]
# ['teeravet siritorn', 1]
# ['pheng sophea', 5]
# ['lee jong rok', 1]
# ['kim song-gun', 43]
# ['suwannachart chatrudee', 4]
# ['song wei', 7]
# ['duan liping', 1]
# ['jin liying', 3]
# ['guo xiao wei', 1]
# ['liu qingzhen', 1]
# ['choi kang-duk', 1]
# ['franco angel', 1]
# ['schubert patrick', 4]
# ['wilke thomas', 4]
# ['safronova vera i', 3]
# ['sazanova anna l', 3]
# ['kuznetsova irina g', 3]
# ['belimov andrey a', 3]
# ['andronov evgeny e', 3]
# ['chirak elizaveta r', 2]
# ['popova janna p', 1]
# ['verkhozina alla v', 1]
# ['willems anne', 45]
# ['tikhonovich igor a', 3]
# ['yang shuo', 1]
# ['li meiqing', 1]
# ['li guizhen', 14]
# ['singh harjodh', 2]
# ['kaur manpreet', 2]
# ['sharma shivani', 2]
# ['kaur lakhwinder', 1]
# ['mishra sunita', 2]
# ['tanuku naga radha srinivas', 8]
# ['pinnaka anil kumar', 12]
# ['pal deepika', 6]
# ['sudan sarabjeet kour', 4]
# ['bisht bhawana', 4]
# ['krishnamurthi srinivasan', 23]
# ['zhu sidong', 1]
# ['lin danqiu', 1]
# ['xiong shangling', 1]
# ['wang xing', 1]
# ['xue zehao', 1]
# ['dong bingxia', 1]
# ['shen xudong', 1]
# ['ma xiangdong', 1]
# ['chen jigang', 1]
# ['yang jifang', 3]
# ['wu yue-hong', 28]
# ['yan jing', 2]
# ['fang chen', 2]
# ['huo ying-yi', 24]
# ['ma wei-lin', 1]
# ['zhang de-min', 2]
# ['wang chun-sheng', 41]
# ['xu xue-wei', 52]
# ['panda ananta n', 1]
# ['mishra samir ranjan', 3]
# ['ray lopamudra', 4]
# ['das surajit', 2]
# ['pattanaik ajit kumar', 3]
# ['adhya tapan kumar', 3]
# ['raina vishakha', 5]
# ['yang qiao', 5]
# ['jiang zhi-wei', 1]
# ['huang cheng-hui', 1]
# ['zhang ruo-nan', 1]
# ['li ling-zhi', 1]
# ['yang guang', 1]
# ['feng li-juan', 1]
# ['yang guang-feng', 1]
# ['zhang heng', 1]
# ['zhang xiao-ling', 1]
# ['mu jun', 2]
# ['kimura nobutada', 2]
# ['watanabe takahito', 1]
# ['suenaga hikaru', 1]
# ['fujihara hidehiko', 1]
# ['futagami taiki', 1]
# ['goto masatoshi', 1]
# ['hirose jun', 1]
# ['yuk kyung-jin', 1]
# ['kim you-tae', 2]
# ['huh chul-sung', 1]
# ['lee ju-hoon', 2]
# ['beltran david', 2]
# ['romo-vaquero maria', 1]
# ['espin juan c', 2]
# ['tomas-barberan francisco a', 2]
# ['selma maria v', 2]
# ['zhang yan-jiao', 12]
# ['liu xu-feng', 1]
# ['kuang bao-zhi', 1]
# ['zhang xi-ying', 32]
# ['zhou ming-yang', 7]
# ['chen shiyong', 2]
# ['gao guang-bin', 2]
# ['chen zheng-jun', 4]
# ['han jigon', 1]
# ['lee dong hoon', 3]
# ['kim mi sun', 18]
# ['chang rachel', 1]
# ['bird lina', 1]
# ['barr casey', 1]
# ['osburn magdalena', 1]
# ['wilbanks elizabeth', 1]
# ['nealson kenneth', 3]
# ['rowe annette', 1]
# ['sharma avinash', 4]
# ['jani kunal', 2]
# ['karodi prachi', 2]
# ['vemuluri venkata ramana', 4]
# ['shivaji sisinthy', 10]
# ['thite vishal', 2]
# ['kajale swapnil', 1]
# ['rahi praveen', 3]
# ['wang qian', 10]
# ['song yali', 3]
# ['choi lina', 2]
# ['liu hongyu', 1]
# ['wang gejiao', 38]
# ['li mingshun', 4]
# ['liu qing', 19]
# ['xin yu-hua', 19]
# ['chen xiu-ling', 2]
# ['chen wen-xin', 4]
# ['anwar nusratgul', 2]
# ['fu geyi', 4]
# ['zhang choangya', 1]
# ['wu yuehong', 2]
# ['mohapatra balaram', 1]
# ['sar pinaki', 1]
# ['kazy sufia khannam', 1]
# ['maiti mrinal kumar', 1]
# ['satyanarayana tulasi', 1]
# ['zhao weiqiang', 1]
# ['cao junwei', 9]
# ['lopez g', 3]
# ['diaz-cardenas c', 3]
# ['david alzate j', 2]
# ['gonzalez l n', 1]
# ['shapiro n', 1]
# ['woyke t', 1]
# ['kyrpides n c', 1]
# ['restrepo s', 2]
# ['baena s', 5]
# ['dione n', 2]
# ['ngom i i', 2]
# ['valles c', 2]
# ['fournier p e', 9]
# ['fonkou m d mbogning', 1]
# ['ma bai-ping', 6]
# ['zhao jian-chao', 2]
# ['cheng juan', 29]
# ['gao zi-wei', 1]
# ['zhang meng-yue', 6]
# ['zhang yi-xuan', 6]
# ['gcebe nomakorinte', 2]
# ['rutten victor p m g', 1]
# ['van pittius nicolaas gey', 1]
# ['naicker brendon', 2]
# ['michel anita l', 1]
# ['chiba makoto', 1]
# ['itabashi takanori', 1]
# ['hirai koujiro', 1]
# ['ishige taichiro', 1]
# ['kawasaki shinji', 3]
# ['rachniyom hathairat', 3]
# ['thamchaipenet arinthip', 16]
# ['liu min-jiao', 9]
# ['jin chun-zhi', 2]
# ['ju yoon-jung', 14]
# ['park dong-jin', 60]
# ['kim chang-jin', 94]
# ['danylec nicolas', 1]
# ['gobl andrea', 1]
# ['stoll dominic a', 1]
# ['hetzer birgit', 1]
# ['kulling sabine e', 1]
# ['huch melanie', 2]
# ['lee hyo-jin', 15]
# ['whang kyung-sook', 39]
# ['li dongmei', 4]
# ['zheng weiwei', 6]
# ['han liyuan', 2]
# ['jiang hao', 2]
# ['thawai chitti', 41]
# ['nam gi gyun', 6]
# ['kim suhyun', 4]
# ['khan inam ullah', 11]
# ['habib neeli', 12]
# ['khan nasr ullah', 1]
# ['ahmed iftikhar', 22]
# ['zhi xiao-yang', 36]
# ['valdehuesa kris nino g', 2]
# ['ramos kristine rose m', 2]
# ['moron llewelyn s', 2]
# ['lee imchang', 4]
# ['nisola grace m', 2]
# ['lee won-keun', 2]
# ['chung wook-jin', 2]
# ['jamjan winai', 1]
# ['sakai kenji', 2]
# ['tashiro yukihiro', 2]
# ['okugawa yuki', 2]
# ['tongpim saowanit', 1]
# ['morales-covarrubias maria soledad', 1]
# ['del carmen bolan-mejia maria', 1]
# ['vela alonso ana isabel', 1]
# ['fernandez-garayzabal jose f', 6]
# ['gomez-gil bruno', 13]
# ['liu xiupian', 21]
# ['du yaping', 19]
# ['zhang xiaorong', 1]
# ['liu zhen', 1]
# ['sun fengqin', 34]
# ['ranchou-peyruse magali', 4]
# ['goni-urriza marisol', 1]
# ['guignard marion', 2]
# ['goas marjorie', 1]
# ['ranchou-peyruse anthony', 5]
# ['guyoneaud remy', 6]
# ['tseng min', 4]
# ['chiang wan-ping', 1]
# ['liao hsuen-chun', 1]
# ['hsieh sung-yuan', 1]
# ['yuan gao-fung', 1]
# ['choi su jung', 13]
# ['penkhrue watsana', 1]
# ['sujarit kanaporn', 3]
# ['kudo takuji', 58]
# ['masaki kazuo', 1]
# ['aizawa tomoyasu', 1]
# ['pathom-aree wasu', 15]
# ['khanongnuch chartchai', 1]
# ['lumyong saisamorn', 6]
# ['dorofeeva lubov v', 4]
# ['starodumova irina p', 1]
# ['krauzova valentina i', 1]
# ['prisyazhnaya natalia v', 1]
# ['vinokurova natalia g', 2]
# ['lysanskaya valentina y', 1]
# ['tarlachkov sergey v', 1]
# ['le roes-hill marilize', 6]
# ['durrell kim', 1]
# ['prins alaric', 1]
# ['meyers paul r', 20]
# ['bouam amar', 1]
# ['heidarieh parvin', 4]
# ['shahraki abodolrazagh hashemi', 1]
# ['pourahmad fazel', 4]
# ['mirsaeidi mehdi', 3]
# ['hashemzadeh mohamad', 4]
# ['baptiste emeline', 1]
# ['levasseur anthony', 4]
# ['drancourt michel', 11]
# ['dai hang', 5]
# ['wang yonglu', 3]
# ['fang yujie', 4]
# ['huang zhenzhou', 2]
# ['kan biao', 4]
# ['wang duochun', 4]
# ['chen sheng-chung', 1]
# ['huang hsing-hua', 1]
# ['lai mei-chin', 1]
# ['weng chieh-yin', 1]
# ['chiu hsiu-hui', 5]
# ['tang sen-lin', 7]
# ['rogozin denis yu', 2]
# ['degermendzhy andrey g', 1]
# ['volokhov dmitriy v', 2]
# ['amselle megan', 2]
# ['bodeis-jones sonya', 1]
# ['delmonte pierluigi', 1]
# ['zhang shuping', 3]
# ['davidson maureen k', 1]
# ['gulland frances m', 1]
# ['chizhikov vladimir e', 2]
# ['zhao lei', 3]
# ['xie pei-bei', 6]
# ['hsu ming-yuan', 3]
# ['schumann peter', 309]
# ['franca luis', 10]
# ['lee ga-eun', 3]
# ['park jin-sook', 5]
# ['perez-cataluna alba', 1]
# ['salas-masso nuria', 1]
# ['figueras maria jose', 10]
# ['zhang yong-guang', 32]
# ['wang hong-fei', 28]
# ['liu yong-hong', 3]
# ['fan miao-chun', 2]
# ['guo yan-qing', 1]
# ['zhang li-ping', 9]
# ['zhu ya-min', 2]
# ['chen wei-min', 4]
# ['lin yan-bing', 2]
# ['wei ge-hong', 5]
# ['zeng yonghui', 6]
# ['wang yanan', 32]
# ['cui henglin', 4]
# ['jiang helong', 6]
# ['wang yu-shuai', 2]
# ['kim hyun chul', 1]
# ['kim young-ok', 33]
# ['nam bo-hye', 23]
# ['kim dong-gyun', 20]
# ['oh mihee', 4]
# ['tahon guillaume', 1]
# ['tytgat bjorn', 1]
# ['lebbe liesbeth', 17]
# ['carlier aurelien', 2]
# ['zhao guo-yan', 3]
# ['shao fei', 1]
# ['zhang mi', 1]
# ['zhang xue-jie', 1]
# ['wang jing-yuan', 2]
# ['fan shou-jin', 1]
# ['dai mei-xue', 3]
# ['baars sophie', 1]
# ['wilharm gottfried', 8]
# ['park in-suk', 7]
# ['choi seok-gwan', 4]
# ['nam young ho', 1]
# ['hwang jung moon', 3]
# ['yim kyung june', 11]
# ['kim jee-hwan', 1]
# ['yadav subhash', 1]
# ['vaddavalli radha', 3]
# ['siripuram srinivas', 1]
# ['eedara ramaprasad veera venkata', 1]
# ['yadav shivani', 2]
# ['rabishankar ojha', 1]
# ['chintalapati venkataramana', 1]
# ['liu yan', 13]
# ['belova svetlana e', 8]
# ['suzina natalia e', 8]
# ['rijpstra w irene c', 21]
# ['sinninghe damste jaap s', 14]
# ['dedysh svetlana n', 30]
# ['roh jeong rae', 2]
# ['lee keun chul', 60]
# ['suh min kuk', 1]
# ['eom mi kyung', 12]
# ['kim kwang kyu', 43]
# ['kim jong-shik', 14]
# ['kim dae-shin', 10]
# ['ko suk-hyung', 10]
# ['shin yong kook', 6]
# ['ayed ameni', 2]
# ['slama nedra', 2]
# ['mankai houda', 2]
# ['bachkouel sarra', 1]
# ['elkahoui salem', 1]
# ['tabbene olfa', 1]
# ['limam ferid', 2]
# ['hettiarachchi sachithra amarin', 1]
# ['lee su-jin', 1]
# ['lee youngdeuk', 2]
# ['kwon young-kyung', 2]
# ['kwon kae kyoung', 29]
# ['yang sung-hyun', 26]
# ['jo eunyoung', 1]
# ['kang do-hyung', 2]
# ['oh chulhong', 2]
# ['iwaki hiroaki', 5]
# ['yamamoto taisei', 1]
# ['hasegawa yoshie', 5]
# ['yuan kai', 3]
# ['cao min', 4]
# ['li jingxin', 4]
# ['amano nanako', 1]
# ['yamamuro ayaka', 1]
# ['miyahara morio', 2]
# ['kouzuma atsushi', 1]
# ['abe takashi', 1]
# ['watanabe kazuya', 14]
# ['pascual javier', 18]
# ['foesel barbel u', 9]
# ['geppert alicia', 4]
# ['huber katharina j', 6]
# ['boedeker christian', 2]
# ['luckner manja', 4]
# ['wanner gerhard', 10]
# ['overmann jorg', 24]
# ['yang zi-wen', 6]
# ['lan liu', 1]
# ['li weilan', 5]
# ['kim yong-seok', 1]
# ['cha chang-jun', 19]
# ['mashima izumi', 2]
# ['liao yu-chieh', 1]
# ['miyakawa hiroshi', 2]
# ['theodorea citra f', 1]
# ['thawboon boonyanit', 1]
# ['thaweboon sroisiri', 1]
# ['scannapieco frank a', 1]
# ['nakazawa futoshi', 3]
# ['hirota kikue', 25]
# ['nishita masatoshi', 2]
# ['tu zhihao', 1]
# ['matsuyama hidetoshi', 16]
# ['yumoto isao', 34]
# ['cui meng-di', 3]
# ['wang xiang', 9]
# ['jiang wan-kui', 3]
# ['hu gang', 9]
# ['yang zhan-gong', 3]
# ['sun gao-jie', 1]
# ['zhu shi-jun', 4]
# ['zhou yi-dong', 2]
# ['hong qing', 20]
# ['luan zhen-dong', 1]
# ['lian chao', 1]
# ['hu yong-hua', 2]
# ['frolov e n', 1]
# ['zayulina k s', 1]
# ['kopitsyn d s', 1]
# ['kublanov i v', 5]
# ['chernyh n a', 9]
# ['leon-barrios milagros', 6]
# ['ramirez-bahena martha helena', 8]
# ['peix alvaro', 47]
# ['kim kwan woo', 1]
# ['lu mei-yu', 1]
# ['wang hui', 10]
# ['yang dahye', 3]
# ['cha seho', 13]
# ['choi jiwon', 2]
# ['xie ruize', 1]
# ['jiao nianzhi', 32]
# ['alharbi sulaiman ali', 2]
# ['alsakkaf waleed a a', 1]
# ['hezbri karima', 8]
# ['rohde manfred', 68]
# ['chen aiping', 1]
# ['cao yan-ru', 11]
# ['he zhong-kan', 2]
# ['guo yan', 2]
# ['yang xuan-xuan', 1]
# ['liang lian-ming', 2]
# ['qu jian-hang', 11]
# ['zhang lu-jie', 1]
# ['fu yun-hui', 1]
# ['li xiao-dan', 2]
# ['li hai-feng', 10]
# ['tian hai-long', 1]
# ['rekha p d', 41]
# ['arun a b', 70]
# ['priyanka p', 1]
# ['kim su min', 1]
# ['rao qiuhua', 1]
# ['tu jiefeng', 1]
# ['zhang jiaonan', 1]
# ['huang minmin', 1]
# ['hu bing', 2]
# ['lin qiu', 1]
# ['luo tuyan', 1]
# ['kuncharoen nattakorn', 2]
# ['pittayakhajonwut pattama', 9]
# ['wang xu-ting', 1]
# ['kurli rashmi', 2]
# ['pansare aabeejjeet n', 2]
# ['khairnar mitesh', 2]
# ['jagtap shubhangi', 2]
# ['patel nisha b', 10]
# ['dastager syed g', 40]
# ['lawson paul a', 68]
# ['shouche yogesh s', 19]
# ['choi jun young', 1]
# ['kim jin ho', 4]
# ['lee pyung cheon', 4]
# ['zhang shuangfei', 1]
# ['sun chongran', 1]
# ['xie jinli', 1]
# ['wei huan', 1]
# ['hu zhong', 2]
# ['nedashkovskaya olga i', 72]
# ['stenkova anna m', 2]
# ['kukhlevskiy andrey d', 7]
# ['zhukova natalia v', 50]
# ['mikhailov valery v', 99]
# ['lee suyeon', 9]
# ['niu xinbin', 1]
# ['cui weiguo', 1]
# ['cui man', 1]
# ['zhang shuqing', 1]
# ['xu bingliang', 1]
# ['gao miao', 7]
# ['pal mohinder', 1]
# ['kumari munesh', 3]
# ['kiran shashi', 2]
# ['salwan richa', 1]
# ['chhibber sanjay', 1]
# ['gulati arvind', 2]
# ['nunez-montero kattia', 1]
# ['leclercq alexandre', 2]
# ['moura alexandra', 1]
# ['vales guillaume', 1]
# ['peraza johnny', 1]
# ['pizarro-cerda javier', 1]
# ['lecuit marc', 2]
# ['teng jade l l', 8]
# ['tang ying', 3]
# ['wong samson s y', 4]
# ['chiu tsz ho', 1]
# ['chan elaine', 1]
# ['ngan antonio h y', 5]
# ['lau susanna k p', 14]
# ['woo patrick c y', 15]
# ['kwon yong min', 3]
# ['kim kyung woo', 1]
# ['kim jaoon young hwan', 1]
# ['choi tae-young', 1]
# ['oh chul hong', 1]
# ['kim sang-jin', 28]
# ['dai yumei', 2]
# ['yim jeeyeo', 1]
# ['lee dong-geol', 5]
# ['kang seunghyun', 1]
# ['nam jin-ju', 1]
# ['kim yeon-jun', 1]
# ['schellenberg johannes', 2]
# ['hardt martin', 3]
# ['ren qiaomeng', 5]
# ['li yuying', 1]
# ['zhang yan', 5]
# ['shi xiaochong', 13]
# ['su ying', 3]
# ['wang xiaolei', 3]
# ['an mingli', 1]
# ['kukolya jozsef', 4]
# ['bata-vidacs ildiko', 2]
# ['luzics szabina', 2]
# ['toth erika', 9]
# ['keki zsuzsa', 17]
# ['nagy istvan', 3]
# ['olasz ferenc', 1]
# ['toth akos', 2]
# ['polonia ana rita m', 1]
# ['barroso cristina', 1]
# ['lage olga', 1]
# ['lobo-da-cunha alexandre', 7]
# ['wang cong', 2]
# ['huang yan', 4]
# ['guo jun', 7]
# ['wu zhengyun', 2]
# ['deng yu', 8]
# ['dai lirong', 4]
# ['ma shichun', 4]
# ['ben ali gam zouhaier', 5]
# ['thioye abdoulaye', 2]
# ['cayol jean-luc', 43]
# ['joseph manon', 13]
# ['fauque guy', 13]
# ['labat marc', 14]
# ['lin long-zhen', 5]
# ['zhang ming-xia', 5]
# ['lv yingying', 1]
# ['klotz franziska', 1]
# ['brinkhoff thorsten', 10]
# ['freese heike m', 4]
# ['wietz matthias', 1]
# ['teske andreas', 1]
# ['simon meinhard', 7]
# ['giebel helge-ansgar', 3]
# ['mohr kathrin i', 4]
# ['moradi azam', 2]
# ['gemperlein katja', 5]
# ['nubel ulrich', 1]
# ['muller rolf', 9]
# ['jia chao', 1]
# ['cui hong-chang', 1]
# ['han yan-qiong', 1]
# ['fu tian-yu', 1]
# ['du rui', 1]
# ['wang xiao-lei', 1]
# ['shi xiao-chong', 1]
# ['mediannikov oleg', 2]
# ['couderc carine', 3]
# ['chen yi-ling', 8]
# ['li yi-shu', 7]
# ['senghor bruno', 1]
# ['bassene hubert', 1]
# ['ruimy raymond', 1]
# ['sokhna cheikh', 3]
# ['lv haoxin', 2]
# ['sahin nurettin', 12]
# ['tani akio', 6]
# ['relich r f', 1]
# ['schmitt b h', 1]
# ['raposo h', 1]
# ['barker l', 1]
# ['blosser s j', 1]
# ['may m', 1]
# ['martins da costa elaine', 2]
# ['azarias guimaraes amanda', 2]
# ['soares de carvalho teotonio', 1]
# ['louzada rodrigues tainara', 1]
# ['de almeida ribeiro paula rose', 2]
# ['de souza moreira fatima m', 1]
# ['dominguez-monino irene', 2]
# ['jurado valme', 13]
# ['gonzalez-pimentel jose l', 1]
# ['miller ana zelia', 1]
# ['hermosin bernardo', 2]
# ['saiz-jimenez cesareo', 14]
# ['choi heejae', 1]
# ['sun ya-wen', 4]
# ['liu jie', 8]
# ['won kyung-hwa', 13]
# ['park gyungsoo', 1]
# ['chin byungsun', 1]
# ['wang qi-jun', 9]
# ['jiang fan', 25]
# ['danzeng wangmu', 5]
# ['zhang yuming', 1]
# ['jiang li', 1]
# ['liu jia', 1]
# ['lu lu', 1]
# ['fan wei', 1]
# ['peng fang', 44]
# ['subhash y', 29]
# ['wu hao', 5]
# ['liu bin', 6]
# ['shao yuanyuan', 1]
# ['ou xiaoyun', 1]
# ['huang fuchang', 2]
# ['christiansen line', 1]
# ['bech pernille kjersgaard', 2]
# ['schultz-johansen mikkel', 2]
# ['martens helle juel', 1]
# ['stougaard peter', 6]
# ['jin qian-wen', 1]
# ['hu dong', 4]
# ['wang liping', 12]
# ['afouda p', 4]
# ['zhang yong', 6]
# ['li chongyang', 1]
# ['wang xiaoqin', 1]
# ['liu jinrong', 1]
# ['friman ville-petri', 3]
# ['muller a', 1]
# ['monti g', 1]
# ['otth c', 1]
# ['sepulveda p', 1]
# ['bittencourt p', 1]
# ['nachum-biala y', 1]
# ['gutierrez r', 1]
# ['harrus s', 1]
# ['osman ghenijan', 8]
# ['mohamed osama abdalla', 1]
# ['jiao jianyu', 1]
# ['ma jinbiao', 1]
# ['vandieken verona', 5]
# ['marshall ian p g', 1]
# ['niemann helge', 4]
# ['engelen bert', 4]
# ['cypionka heribert', 6]
# ['chiou tai-ying', 1]
# ['suda wataru', 4]
# ['oshima kenshiro', 7]
# ['hattori masahira', 10]
# ['matsuzaki chiaki', 1]
# ['yamamoto kenji', 1]
# ['takahashi tomoya', 1]
# ['nobrega maria s', 1]
# ['silva bruno s', 1]
# ['leomil luciana', 2]
# ['tschoeke diogo antonio', 1]
# ['campeao mariana e', 2]
# ['garcia gizele d', 1]
# ['dias graciela a', 1]
# ['vieira veronica v', 1]
# ['thompson cristiane c', 6]
# ['thompson fabiano l', 23]
# ['lopez-hermoso clara', 1]
# ['de la haba rafael r', 8]
# ['sanchez-porro cristina', 35]
# ['proenca diogo n', 1]
# ['varghese neha', 1]
# ['shapiro nicole', 5]
# ['kyrpides nikos c', 6]
# ['morais paula v', 15]
# ['waleron malgorzata', 2]
# ['misztak agnieszka', 1]
# ['waleron michal', 1]
# ['franczuk martyna', 1]
# ['wielgomas bartosz', 1]
# ['waleron krzysztof', 1]
# ['vitton v', 7]
# ['benezech a', 5]
# ['million m', 3]
# ['wullschleger stephan', 1]
# ['jans christoph', 1]
# ['seifert clelia', 1]
# ['baumgartner sarah', 1]
# ['lacroix christophe', 2]
# ['bonfoh bassirou', 1]
# ['stevens marc j a', 1]
# ['meile leo', 2]
# ['adhikary sadhana', 2]
# ['bisgaard magne', 12]
# ['nicklas werner', 5]
# ['christensen henrik', 15]
# ['bu ji-hye', 1]
# ['bae seung seob', 8]
# ['jung jaejoon', 3]
# ['chung dawoon', 1]
# ['baek kyunghwa', 8]
# ['balabanova larissa a', 2]
# ['bakunina irina y', 2]
# ['jeon jongguen', 2]
# ['lee jae-jin', 41]
# ['park sangkyu', 16]
# ['nishimura yuki', 1]
# ['modesto monica', 6]
# ['michelini samanta', 6]
# ['oki kaihei', 3]
# ['biavati bruno', 5]
# ['mattarelli paola', 6]
# ['xiong mengjie', 4]
# ['song lei', 21]
# ['li wenying', 2]
# ['kim eun tae', 1]
# ['kim sang bum', 1]
# ['jeong ha yeon', 1]
# ['park beom young', 1]
# ['srinivasan sathiyaraj', 53]
# ['an dong-shan', 24]
# ['kim kyoung-ho', 19]
# ['lee jae-bong', 9]
# ['hong sumin', 1]
# ['park su-jin', 15]
# ['chen yufei', 1]
# ['oh ji hye', 2]
# ['seo hyun-seok', 14]
# ['lee jung-hyun', 20]
# ['guo jian-wei', 13]
# ['wang yun', 23]
# ['bobodzhanova khursheda', 1]
# ['xiao tao', 1]
# ['tegtmeier dorothee', 2]
# ['belitz alexandra', 1]
# ['radek renate', 4]
# ['heimerl thomas', 1]
# ['brune andreas', 8]
# ['mohamad osama abdalla', 1]
# ['jiang chenying', 1]
# ['hilgarth maik', 1]
# ['fuertes sandra', 1]
# ['ehrmann matthias', 1]
# ['vogel rudi f', 8]
# ['kusada hiroyuki', 1]
# ['kameyama keishi', 1]
# ['kamagata yoichi', 38]
# ['xu guangtang', 1]
# ['lin caili', 1]
# ['wang xizhuo', 1]
# ['divyasree b', 9]
# ['suresh g', 3]
# ['yang xiao-deng', 2]
# ['he hai-lun', 3]
# ['ning daliang', 1]
# ['du zongjun', 2]
# ['kumar narender', 7]
# ['chaudhry vasvi', 2]
# ['sahni girish', 1]
# ['puche rafael', 1]
# ['ferres ignacio', 1]
# ['caraballo lizeth', 1]
# ['rangel yaritza', 1]
# ['picardeau mathieu', 2]
# ['takiff howard', 1]
# ['iraola gregorio', 3]
# ['ge baosheng', 1]
# ['nahar shamsun', 1]
# ['ueki atsuko', 24]
# ['goto kazushi', 2]
# ['kaku nobuo', 14]
# ['ueki katsuji', 24]
# ['sheu der-shyan', 11]
# ['zhang xiaoling', 1]
# ['li lingzhi', 1]
# ['zhang ruonan', 1]
# ['feng lijuan', 1]
# ['yu zhili', 1]
# ['li shuying', 1]
# ['jiang zhuang', 1]
# ['zhou jinru', 1]
# ['an qianli', 2]
# ['oguntoyinbo folarin a', 1]
# ['cho gyu-sung', 2]
# ['kabisch jan', 1]
# ['neve horst', 1]
# ['bockelmann wilhelm', 1]
# ['wenning mareike', 15]
# ['franz charles m a p', 7]
# ['zhang bo', 5]
# ['liu zhi-qiang', 3]
# ['zheng yu-guo', 2]
# ['landwehr wiebke', 1]
# ['ruckert christian', 5]
# ['kalinowski jorn', 5]
# ['goesmann alexander', 2]
# ['mack matthias', 1]
# ['hahnke richard l', 2]
# ['martin karin', 23]
# ['stadler marc', 3]
# ['huang meng-meng', 3]
# ['guo li-li', 2]
# ['shao zong-ze', 2]
# ['oh young joon', 2]
# ['jang ja-young', 2]
# ['lim seul ki', 2]
# ['kwon min-sung', 2]
# ['lee jieun', 2]
# ['kim namhee', 1]
# ['shin mi-young', 1]
# ['park hyo kyeong', 1]
# ['seo myung-ji', 11]
# ['choi hak-jong', 6]
# ['okiria joseph', 5]
# ['lee dae sung', 13]
# ['wiese jutta', 9]
# ['saha mahasweta', 1]
# ['wenzel-storjohann arlette', 1]
# ['weinberger florian', 1]
# ['schmaljohann rolf', 3]
# ['imhoff johannes f', 13]
# ['gao yan', 2]
# ['wang ning', 6]
# ['mahmud otkur', 1]
# ['sun jian', 1]
# ['zhang tao', 6]
# ['zhan faqiang', 1]
# ['zhang zhidong', 4]
# ['han xi-bin', 1]
# ['passet virginie', 4]
# ['brisse sylvain', 9]
# ['liu zongdong', 1]
# ['lu binghuai', 1]
# ['kawata misho', 1]
# ['tsukamoto ami', 1]
# ['isozaki ryohei', 1]
# ['nobukawa shohei', 1]
# ['kawahara natsuki', 1]
# ['akutsu shoko', 1]
# ['suzuki masato', 1]
# ['asanuma narito', 2]
# ['nicaise b', 1]
# ['bretelle f', 8]
# ['fenollar f', 13]
# ['choi min kyoung', 1]
# ['nam sang-jip', 1]
# ['han yushan', 3]
# ['guo wei', 5]
# ['liao shuijiao', 5]
# ['andrieu claudia', 5]
# ['djaballah c e', 1]
# ['kitouni m', 1]
# ['bhardwaj ayanka', 2]
# ['vyas bhawna', 2]
# ['zheng min-ling', 1]
# ['wang juan', 2]
# ['li song', 1]
# ['chen cha', 4]
# ['qu ping-hua', 4]
# ['guan hui-lin', 2]
# ['zhang yun-jiao', 12]
# ['lu xiao-ju', 2]
# ['jia man', 5]
# ['zhang zheng-yun', 2]
# ['gao xu-hong', 3]
# ['ma yong-chun', 4]
# ['tian fei', 4]
# ['tang shu-kun', 121]
# ['jo eojin', 2]
# ['park soon-nang', 3]
# ['lim yun kyong', 3]
# ['paek jayoung', 14]
# ['shin yeseul', 10]
# ['kim hongik', 11]
# ['kim si hyun', 1]
# ['shin jeong hwan', 3]
# ['chang young-hyo', 22]
# ['kook joong-ki', 7]
# ['boutin sebastien', 1]
# ['niemhom nantawan', 6]
# ['yasumoto-hirose mina', 9]
# ['kasai hiroaki', 67]
# ['veyisoglu aysel', 17]
# ['sahin nevzat', 34]
# ['wang yue-qiang', 2]
# ['liu xiao-ming', 1]
# ['tang jia', 5]
# ['yang gui-qin', 5]
# ['yu zhen', 11]
# ['timilsina sujan', 1]
# ['minsavage gerald v', 1]
# ['preston james', 1]
# ['newberry eric a', 1]
# ['paret matthews l', 1]
# ['goss erica m', 1]
# ['jones jeffrey b', 3]
# ['vallad gary e', 1]
# ['khare kaustubh', 1]
# ['senik svetlana', 1]
# ['bandal jayashree', 1]
# ['rale vinay', 1]
# ['lee jaegeun', 1]
# ['hyeon jong woo', 8]
# ['hyun seogang', 1]
# ['li wenchao', 7]
# ['wang jiabin', 2]
# ['tian yuanyuan', 2]
# ['wang yan', 13]
# ['liu tingwei', 1]
# ['sun pengyang', 1]
# ['cao chenxi', 1]
# ['guo menglong', 1]
# ['du junran', 1]
# ['zhou chenyan', 3]
# ['zhu wuling', 2]
# ['sun le-ni', 6]
# ['pan dan-dan', 1]
# ['wu xiang-wei', 1]
# ['yang en-dong', 6]
# ['hua ri-mao', 2]
# ['park hye yoon', 3]
# ['guo ling-yun', 9]
# ['ling si-kai', 7]
# ['ashraf simin', 1]
# ['soudi mohammad reza', 1]
# ['yang you-jian', 1]
# ['zhang yan-ting', 1]
# ['chen guo-qiang', 2]
# ['cheng dan', 2]
# ['qiu ji-guo', 1]
# ['he qin', 4]
# ['he jian', 34]
# ['kim sang yong', 3]
# ['yu hong shan', 1]
# ['lee jae hak', 1]
# ['han yi-fan', 1]
# ['zhang wen-wu', 8]
# ['ji mukan', 1]
# ['tang sihui', 1]
# ['ferrari belinda c', 1]
# ['ding peng', 3]
# ['bai juan-luan', 5]
# ['wang tian-tian', 2]
# ['cao cheng-liang', 11]
# ['jiang ji-hong', 19]
# ['han ji-hye', 15]
# ['qu zhi', 8]
# ['bao xiao-dong', 1]
# ['xie qing-yi', 16]
# ['zhao you-xing', 1]
# ['yan bing', 1]
# ['dai hao-fu', 1]
# ['chen hui-qin', 1]
# ['pillonetto marcelo', 1]
# ['arend lavinia n', 1]
# ['faoro helisson', 1]
# ["d'espindula helena r s", 1]
# ['smits theo h m', 3]
# ['mira marcelo t', 1]
# ['rezzonico fabio', 2]
# ['mohany mohamed', 1]
# ['chinnathambi arunachalam', 1]
# ['liu chongxi', 76]
# ['han chuanyu', 6]
# ['yan kai', 12]
# ['weilan li', 1]
# ['lin shih-yao', 55]
# ['hameed asif', 52]
# ['hsu yi-han', 46]
# ['liu you-cheng', 46]
# ['hung mei-hua', 7]
# ['lai wei-an', 61]
# ['sansosti maria cristina', 1]
# ['de filippo carlotta', 1]
# ['cavalieri duccio', 1]
# ['qvirist linnea', 1]
# ['andlid thomas', 1]
# ['spiezio caterina', 4]
# ['sandri camillo', 4]
# ['pascarelli stefano', 1]
# ['sgorbati barbara', 2]
# ['dai yu-mei', 2]
# ['zhang ling-li', 2]
# ['li yan', 18]
# ['li yu-qian', 5]
# ['deng xiao-hui', 1]
# ['wang ting-ting', 1]
# ['yang feng', 1]
# ['tian yong-qiang', 3]
# ['li na', 2]
# ['zhou xing-mei', 1]
# ['liu xiao-feng', 2]
# ['hsieh yu-ting', 3]
# ['lee soon-youl', 5]
# ['yu yang', 2]
# ['cao peng', 1]
# ['li chenxu', 1]
# ['yang fan', 5]
# ['li mutong', 1]
# ['hayashi kazukuni', 1]
# ['golke jan', 9]
# ['anderson james', 1]
# ['wan xuehua', 2]
# ['hou shaobin', 3]
# ['chain patrick s g', 2]
# ['prescott rebecca d', 1]
# ['donachie stuart p', 8]
# ['kim ji-young', 7]
# ['park so-hyun', 5]
# ['lee dong-heon', 23]
# ['song gwanpil', 1]
# ['kim young-ju', 6]
# ['liu bo', 15]
# ['liu guo-hong', 12]
# ['wang xiao-ying', 1]
# ['wang jie-ping', 6]
# ['zhu yu-jing', 5]
# ['zhang hai-feng', 2]
# ['sengonca cetin', 9]
# ['ekwe adaeze precious', 2]
# ...
# ['patole milind', 1]
# ['hippe h', 2]
# ['fardeau m l', 2]
# ['lu zhi-tang', 1]
# ['fernandez-lopez manuel', 1]
# ['matsubara hiroshige', 1]
# ['matsumura terumi', 1]
# ['iwaki masaharu', 1]
# ['niwa motohiro', 1]
# ['dasman', 1]
# ["kajiyama shin'ichiro", 1]
# ['yagi masahiro', 1]
# ['fukusaki ei-ichiro', 1]
# ['kobayashi akio', 1]
# ['vybiral dietmar', 4]
# ['velimirov branko', 2]
# ['quillevere morgane', 1]
# ['donval jean-pierre', 1]
# ['raguenes gerard', 2]
# ['barcenilla adela', 1]
# ['stewart colin s', 1]
# ['wullenweber jorg', 1]
# ['schulte martina', 1]
# ['weil hans-peter', 1]
# ['von eiff christof', 1]
# ['kim eun suk', 1]
# ['kang sa-ouk', 1]
# ['hah yung chil', 2]
# ['shinmaru sachie', 1]
# ['nishiyama toshiharu', 1]
# ['pandey k k', 1]
# ['janssens d', 2]
# ['iivanainen eila', 1]
# ['suutari merja', 1]
# ['seppanen jaana', 1]
# ['katila marja-leena', 1]
# ['baida nader', 1]
# ['yazourh asmae', 1]
# ['singer elisabeth', 2]
# ['izard daniel', 2]
# ['munson mark a', 1]
# ['spratt david a', 1]
# ['hernandez-eugenio guadalupe', 2]
# ['kawasaki kosei', 1]
# ['hishinuma megumi', 1]
# ['naumann dieter', 1]
# ['alarico susana', 1]
# ['simmering rainer', 2]
# ['schwiertz andreas', 1]
# ['le blay gwenaelle', 1]
# ['gruhl barbel', 1]
# ['collins matrhew d', 1]
# ['collins mattew d', 1]
# ['hutson roger', 1]
# ['meier paul r', 1]
# ['mitchell paul d', 1]
# ['frank daniel n', 1]
# ['simser jason a', 1]
# ['palmer ann t', 1]
# ['santos joao', 1]
# ['travassos pedro', 1]
# ['wait robin', 1]
# ['weijma jan', 1]
# ['gotz d', 1]
# ['rushdi a i', 1]
# ['simoneit b r t', 1]
# ['reysenbach a l', 1]
# ['bonch-osmolovskaya elisaveta a', 1]
# ['aruga shinobu', 1]
# ['kanagawa takahiro', 1]
# ['benlloch susana', 2]
# ['mata-roig manuel', 1]
# ['squartini andrea', 1]
# ['struffi paolo', 1]
# ['doring heidi', 1]
# ['selenska-pobell sonja', 1]
# ['tola elisabetta', 1]
# ['giacomini alessio', 1]
# ['vendramin elena', 1]
# ['casella sergio', 1]
# ['nuti marco p', 1]
# ['ahn jong-seog', 1]
# ['mheen tae-ick', 1]
# ['valens maria', 1]
# ['li zhiyu', 1]
# ['yamagata shuzo', 1]
# ['deguchi takashi', 1]
# ['laday miklos', 1]
# ['oravecz orsolya', 1]
# ['hornok laszlo', 1]
# ['bakalidou agapia', 1]
# ['berchtold manfred', 1]
# ['kuhnigk thomas', 1]
# ['wenzel marika', 1]
# ['seyfried markus', 1]
# ['lyon delina', 1]
# ['warnick thomas a', 1]
# ['methe barbara a', 1]
# ['leschine susan b', 1]
# ['sakala rita m', 1]
# ['hayashidani hideki', 1]
# ['kaneuchi choji', 1]
# ['ogawa masuo', 1]
# ['weiss n', 5]
# ['linos alexandros', 1]
# ['berekaa mahmoud m', 1]
# ['liu jian-rong', 1]
# ['mckenzie christine a', 1]
# ['seviour elizabeth m', 1]
# ['breymann sabine', 1]
# ['prauser helmut', 1]
# ['poliakova a v', 1]
# ['chernov i iu', 1]
# ['dangler charles a', 1]
# ['cullen john m', 1]
# ['yonemitsu yoshitomo', 1]
# ['matsushita mayumi', 1]
# ['kuraishi hiroshi', 1]
# ["gad'on nasser", 1]
# ['mccartney anne l', 1]
# ['gavrish ekaterina yu', 1]
# ['yashina svetlana g', 1]
# ['lorin valerie', 1]
# ['henry christine', 1]
# ['hong long', 1]
# ['forsyth g', 1]
# ['heyndrickx m', 1]
# ['balcaen a', 1]
# ['verhelst a', 1]
# ['ljungh a', 1]
# ['hansson h b', 1]
# ['phillips robert w', 1]
# ['berry christopher j', 1]
# ['fliermans carl', 1]
# ['white david c', 1]
# ['shimkets lawrence j', 1]
# ['vilalta n euras', 1]
# ['van der wielen paul w j j', 1]
# ['rovers gerben m l l', 1]
# ['scheepens judith m a', 1]
# ['biesterveld steef', 1]
# ['tsapin alexandre i', 1]
# ['ghiorse william c', 1]
# ['kim bongcheol', 1]
# ['shintani tomoyoshi', 1]
# ['magnusson jesper', 1]
# ['schnurer johan', 1]
# ['saono susono', 1]
# ['breitenstein antje', 1]
# ['haertig claus', 1]
# ['spanevello mark d', 1]
# ['zhang weizhou', 2]
# ['banta amy', 1]
# ['ohta yoshiyuki', 1]
# ['tor jason m', 1]
# ['gaw van praagh catherine v', 1]
# ['lan g q', 1]
# ['ho y w', 1]
# ['abdullah n', 1]
# ['birkbeck t h', 1]
# ['laidler l a', 1]
# ['grant a n', 1]
# ['cox d i', 1]
# ['messick joanne b', 1]
# ['walker pamela g', 1]
# ['raphael william', 1]
# ['berent linda', 1]
# ['shi xun', 1]
# ['nzula sazini', 1]
# ['govan john r w', 1]
# ['lee chul ho', 1]
# ['kim bang hyun', 1]
# ['thiemann volker', 1]
# ['laue heike', 1]
# ['abed raeid m m', 1]
# ['hernandez-marine mariona', 1]
# ['rees gavin n', 1]
# ['harfoot christopher g', 1]
# ['schoenborn liesbeth', 1]
# ['fernandez e', 1]
# ['mityushina lubov l', 1]
# ['ferreira ana margarida', 1]
# ['ramos ana', 1]
# ['krooneman j', 1]
# ['faber f', 1]
# ['alderkamp a c', 1]
# ['elferink s j h w oude', 1]
# ['driehuis f', 1]
# ['gottschal j c', 2]
# ['horn matthias', 1]
# ['fritsche thomas r', 1]
# ['linner tanja', 1]
# ['gautom romesh k', 1]
# ['harzenetter marit d', 1]
# ['abbas ibrahim', 2]
# ['fischer ulrike r', 1]
# ['delorme sandrine', 1]
# ['lemanceau philippe', 1]
# ['corberand therese', 1]
# ['cheigh chan-ick', 1]
# ['kim seong-bo', 1]
# ['lee jung-choul', 1]
# ['choi sung-won', 1]
# ['nakamura l k', 2]
# ['shida o', 2]
# ['takagi h', 1]
# ['komagata k', 2]
# ['busse h j', 4]
# ['nuutinen j', 1]
# ['tsitko i v', 1]
# ['denner e b m', 1]
# ['vauterin l', 1]
# ['salkinoja-salonen m s', 2]
# ['evers stephan', 1]
# ['kaim georg', 1]
# ['seo weon-taek', 1]
# ['kho yung hee', 2]
# ['heller remy', 1]
# ['van laere guy', 1]
# ['sander anna', 1]
# ['dehio christoph', 1]
# ['han jang-il', 1]
# ['kim young-bae', 1]
# ['dabboussi fouad', 1]
# ['hamze monzer', 1]
# ['geoffroy valerie', 1]
# ['tyrrell gregory j', 1]
# ['turnbull leeann', 1]
# ['lefebvre johanne', 1]
# ['lovgren marguerite', 1]
# ['akihara saki', 1]
# ['suzuki toshiharu', 1]
# ['iwasaki toshio', 1]
# ['uzawa taketoshi', 1]
# ['hara kurt', 1]
# ['nemoto naoki', 1]
# ['kon takahide', 1]
# ['ueki toshiaki', 1]
# ['brandao p f', 1]
# ['maldonado l a', 1]
# ['ward a c', 2]
# ['bull a t', 1]
# ['yumoto noboru', 1]
# ['taguchi takahisa', 1]
# ['yoshikawa susumu', 1]
# ['alexeeva yuliya v', 1]
# ['zukova natalia v', 1]
# ['yuki norikatsu', 1]
# ['kado yukiko', 1]
# ['shimazaki tomoko', 1]
# ['yuyama teruhiko', 1]
# ['collins matthhew d', 1]
# ['jimenez francisco', 1]
# ['gilhaus helga', 1]
# ['beer w', 1]
# ['mietke henriette', 1]
# ['gelderblom h r', 1]
# ['burghardt barbel', 1]
# ['voigt w', 1]
# ['reissbrodt r', 1]
# ['denger karin', 1]
# ['muxi lucia', 1]
# ['bjorkroth k johanna', 1]
# ['geisen rolf', 1]
# ['korkeala hannu j', 1]
# ['daane l l', 1]
# ['harjono i', 1]
# ['barns s m', 1]
# ['launen l a', 1]
# ['palleron n j', 1]
# ['haggblom m m', 2]
# ['kim chul-joong', 1]
# ['poco sergio e jr', 1]
# ['sato michiko', 1]
# ['ikeda tetsuro', 1]
# ['kalfas sotos', 1]
# ['sundqvist goran', 1]
# ['hoshino etsuro', 1]
# ['reva oleg n', 1]
# ['smirnov valerie v', 1]
# ['pettersson bertil', 1]
# ['coram nicolette j', 1]
# ['rawlings douglas e', 1]
# ['hoyles l', 7]
# ['tornqvist e', 1]
# ['von essen r', 1]
# ['borodina elena', 1]
# ['ward-rainey naomi l', 1]
# ['garnova e s', 2]
# ['tee w', 1]
# ['midolo p', 1]
# ['kerr t', 1]
# ['dyall-smith m l', 1]
# ['riessen s', 1]
# ['antranikian g', 3]
# ['yakimov m m', 1]
# ['giuliano l', 1]
# ['chernikova t n', 1]
# ['gentile g', 1]
# ['abraham w r', 2]
# ['lunsdorf h', 1]
# ['timmis k n', 1]
# ['golyshin p n', 1]
# ['keis s', 1]
# ['shaheen r', 1]
# ['jones d t', 1]
# ['dorofeeva l v', 1]
# ['dobrovolskaya t g', 1]
# ['streshinskaya g m', 1]
# ['subbotin s a', 1]
# ['tiedje j m', 1]
# ['bruns a', 1]
# ['berthe-corti l', 1]
# ['ivanova e p', 2]
# ['nedashkovskaya o i', 1]
# ['chun j', 2]
# ['frolova g m', 1]
# ['vysotskii m v', 1]
# ['huq a', 1]
# ['colwell r r', 1]
# ['whitford m f', 1]
# ['yanke l j', 1]
# ['forster r j', 1]
# ['teather r m', 1]
# ['chin k j', 1]
# ['liesack w', 1]
# ['lo presti f', 1]
# ['riffard s', 1]
# ['meugnier h', 2]
# ['reyrolle m', 1]
# ['lasne y', 1]
# ['grimont p a', 2]
# ['grimont f', 1]
# ['benson r f', 2]
# ['brenner d j', 2]
# ['etienne j', 1]
# ['freney j', 1]
# ['lu j', 1]
# ['nogi y', 1]
# ['takami h', 1]
# ['woo p c', 1]
# ['teng j l', 1]
# ['wong m k', 1]
# ['lau s k', 1]
# ['chung w k', 1]
# ['yumoto i', 2]
# ['kusano t', 1]
# ['shingyo t', 1]
# ['nodasaka y', 2]
# ['matsuyama h', 1]
# ['okuyama h', 1]
# ['takahata y', 1]
# ['nishijima m', 1]
# ['hoaki t', 1]
# ['maruyama t', 1]
# ['robertson b r', 1]
# ["o'rourke j l", 1]
# ['on s l', 2]
# ['lee a', 1]
# ['lai m c', 1]
# ['chen s c', 1]
# ['stohr r', 1]
# ['waberski a', 1]
# ['volker h', 2]
# ['thomm m', 2]
# ['masuzawa t', 1]
# ['takada n', 1]
# ['kudeken m', 1]
# ['fukui t', 1]
# ['yano y', 1]
# ['ishiguro f', 1]
# ['kawamura y', 1]
# ['imai y', 1]
# ['ezaki t', 1]
# ['tamura t', 1]
# ['hayakawa m', 1]
# ['hatano k', 2]
# ['straub k l', 1]
# ['buchholz-cleven b e', 1]
# ['tzellas n', 1]
# ['coleman b', 1]
# ['spratt d a', 1]
# ['wery n', 2]
# ['moricet j m', 1]
# ['cueff v', 1]
# ['jean j', 1]
# ['pignet p', 2]
# ['lesongeur f', 2]
# ['cambon-bonavita m a', 2]
# ['barbier g', 2]
# ['brim h', 1]
# ['diels l', 1]
# ['mergeay m', 2]
# ['kersters k', 1]
# ['wilson r w', 1]
# ['steingrube v a', 1]
# ['bottger e c', 1]
# ['springer b', 1]
# ['brown-elliott b a', 1]
# ['vincent v', 1]
# ['jost k c jr', 1]
# ['zhang y', 2]
# ['garcia m j', 1]
# ['chiu s h', 1]
# ['onyi g o', 1]
# ['rossmoore h', 1]
# ['nash d r', 1]
# ['wallace r j jr', 1]
# ['hommez j', 1]
# ['teixeira l m', 1]
# ['carvalho m g', 1]
# ['espinola m m', 1]
# ['douglas m p', 1]
# ['facklam r r', 1]
# ['chen w m', 1]
# ['laevens s', 3]
# ['lee t m', 1]
# ['renaud f n', 1]
# ['aubel d', 1]
# ['riegel p', 1]
# ['bollet c', 2]
# ['willumsen p', 1]
# ['karlson u', 1]
# ['wauters g', 2]
# ['charlier j', 1]
# ['janssens m', 1]
# ['delmee m', 1]
# ['suarez a', 1]
# ['guerra v', 1]
# ['lizama c', 1]
# ['palmisano m m', 1]
# ['duncan k e', 1]
# ['istock c a', 1]
# ['cohan f m', 1]
# ['von wintzingerode f', 2]
# ['siddiqui r a', 2]
# ['rosick u', 2]
# ['suzuki m', 1]
# ['nakagawa y', 1]
# ['harayama s', 1]
# ['yamamoto s', 1]
# ['bouchotroch s', 1]
# ['quesada e', 1]
# ['del moral a', 1]
# ['llamas i', 1]
# ['bejar v', 1]
# ['mitiushina l l', 1]
# ['iusupov s k', 1]
# ['han x y', 1]
# ['pham a s', 1]
# ['nguyen k u', 1]
# ['smythe w r', 1]
# ['ordonez n g', 1]
# ['jacobson k l', 1]
# ['tarrand j j', 1]
# ['peltola j s', 1]
# ['andersson m a', 1]
# ['auling g', 1]
# ['rainey f a', 3]
# ['leijdekkers p', 1]
# ['wesselink j j', 1]
# ['bakkes p', 1]
# ['pol a', 1]
# ['van der drift c', 1]
# ['den camp h j', 1]
# ['kaluzhnaya m', 1]
# ['khmelenina v', 1]
# ['eshinimaev b', 1]
# ['suzina n', 1]
# ['nikitin d', 1]
# ['solonin a', 1]
# ['lin j l', 1]
# ['mcdonald i', 1]
# ['murrell c', 1]
# ['trotsenko y', 1]
# ['richter e', 1]
# ['niemann s', 1]
# ['ruesch-gerdes s', 1]
# ['harmsen d', 1]
# ['doskar j', 1]
# ['dehio c', 1]
# ['lanz c', 1]
# ['pohl r', 1]
# ['behrens p', 1]
# ['bermond d', 1]
# ['piemont y', 1]
# ['pelz k', 1]
# ['sander a', 1]
# ['sikorski j', 1]
# ['wackernagel w', 1]
# ['kim b c', 1]
# ['grote r', 1]
# ['lee d w', 1]
# ['pyun y r', 2]
# ['takeuchi m', 3]
# ['kang s s', 2]
# ['lee k c', 4]
# ['lee e s', 1]
# ['kho y h', 4]
# ['kang k h', 4]
# ['lee s d', 2]
# ['kim e s', 1]
# ['min k l', 1]
# ['lee w y', 1]
# ['kang s o', 1]
# ['hah y c', 2]
# ['egan s', 1]
# ['holmstrom c', 1]
# ['kjelleberg s', 1]
# ['lee j s', 1]
# ['shin y k', 1]
# ['mahenthiralingam e', 1]
# ['henry d', 1]
# ['lipuma j j', 1]
# ['gillis m', 3]
# ['speert d p', 1]
# ['altwegg m', 1]
# ['mallet m n', 1]
# ['garcia m t', 1]
# ['vargas c', 1]
# ['canovas d', 1]
# ['nieto j j', 1]
# ['aznar r', 1]
# ['wink j', 1]
# ['takai k', 2]
# ['komatsu t', 1]
# ['horikoshi k', 1]
# ['thomson l f', 1]
# ['kushmaro a', 1]
# ['banin e', 1]
# ['loya y', 1]
# ['koussemon m', 1]
# ['combet-blanc y', 1]
# ['patel b k', 1]
# ['cayol j l', 1]
# ['xu y', 1]
# ['liu y', 1]
# ['zhou p', 1]
# ['haridon s l', 1]
# ['bonch-osmolovskaya e', 1]
# ['holmstrom g', 1]
# ['persson a', 1]
# ['sjoden b', 2]
# ['fuentes-ramirez l e', 1]
# ['bustillos-cristales r', 1]
# ['tapia-hernandez a', 1]
# ['jimenez-salgado t', 1]
# ['wang e t', 2]
# ['martinez-romero e', 1]
# ['sutra l', 1]
# ['christen r', 2]
# ['simoneau p', 1]
# ['gardan l', 1]
# ['willcox m d', 1]
# ['zhu h', 1]
# ['knox k w', 1]
# ['behrendt u', 1]
# ['ulrich a', 1]
# ['schattke a', 1]
# ['gross r', 1]
# ['moser d p', 1]
# ['onstott t c', 1]
# ['spoelstra n', 1]
# ['pfiffner s m', 1]
# ['dohnalkova a', 1]
# ['fredrickson j k', 1]
# ['humphry d r', 1]
# ['george a', 1]
# ['black g w', 1]
# ['cummings s p', 2]
# ['baida n', 1]
# ['yazourh a', 1]
# ['singer e', 1]
# ['izard d', 1]
# ['melito p l', 1]
# ['munro c', 1]
# ['chipman p r', 1]
# ['woodward d l', 1]
# ['booth t f', 1]
# ['rodgers f g', 1]
# ['ntougias s', 1]
# ['russell n j', 1]
# ['huang y', 1]
# ['qi w', 2]
# ['lu z', 2]
# ['liu z', 2]
# ['gumaelius l', 1]
# ['magnusson g', 1]
# ['pettersson b', 2]
# ['dalhammar g', 1]
# ['barbeyron t', 1]
# ['corre e', 1]
# ['kloareg b', 1]
# ['potin p', 1]
# ['etchebehere c', 1]
# ['errazquin m i', 1]
# ['dabert p', 1]
# ['moletta r', 1]
# ['muxi l', 1]
# ['jang s s', 1]
# ['arata a b', 1]
# ['hansen l m', 1]
# ['earley d l', 1]
# ['vandamme p a', 1]
# ['timoney p j', 1]
# ['hirsh d c', 1]
# ['tsukamoto t', 1]
# ['murata h', 1]
# ['shirata a', 1]
# ['tan z y', 1]
# ['kan f l', 1]
# ['peng g x', 1]
# ['reinhold-hurek b', 1]
# ['chen w x', 1]
# ['nikolaitchouk n', 2]
# ['westling k', 1]
# ['brennan n m', 1]
# ['brown r', 1]
# ['beresford t p', 1]
# ['simpson p j', 1]
# ['fox p f', 1]
# ['cogan t m', 1]
# ['denner e b', 2]
# ['paukner s', 1]
# ['moore e r', 1]
# ['wanner g', 1]
# ['lubitz w', 2]
# ['fournier d', 1]
# ['mouton c', 1]
# ['lapierre p', 1]
# ['kato t', 1]
# ['okuda k', 1]
# ['menard c', 1]
# ['choi s h', 2]
# ['adeleke a a', 1]
# ['fields b s', 1]
# ['daneshvar m i', 1]
# ['pruckler j m', 1]
# ['ratcliff r m', 1]
# ['harrison t g', 1]
# ['weyant r s', 1]
# ['birtles r j', 1]
# ['halablab m a', 1]
# ['ohlen m', 2]
# ['hannant w', 1]
# ['govan j r', 1]
# ['urbance j w', 1]
# ['bratina b j', 1]
# ['stoddard s f', 1]
# ['schmidt t m', 1]
# ['trotsenko y a', 2]
# ['leisinger t', 1]
# ['langendijk p s', 1]
# ['kulik e m', 1]
# ['sandmeier h', 1]
# ['meyer j', 1]
# ['van der hoeven j s', 1]
# ['gorshkova n m', 1]
# ['nicolau d v', 1]
# ['bouzar h', 1]
# ['jones j b', 1]
# ['velazquez e', 1]
# ['igual j m', 1]
# ['fernandez m p', 1]
# ['munoz e', 1]
# ['abril a', 1]
# ['toro n', 1]
# ['normand p', 1]
# ['cervantes e', 1]
# ['mark b', 1]
# ['turkiewicz m', 1]
# ['blum j s', 1]
# ['stolz j f', 1]
# ['oren a', 1]
# ['oremland r s', 1]
# ['schlesner h', 1]
# ['wehmeyer u', 1]
# ['pascual c', 2]
# ['henderson d', 1]
# ['moon e y', 1]
# ['ko s h', 1]
# ['lee d s', 1]
# ['lee h s', 1]
# ['bae k s', 1]
# ['lawson a j', 1]
# ['logan j m', 1]
# ['stanley j', 1]
# ['wise m g', 1]
# ['mcarthur j v', 1]
# ['shimkets l j', 1]
# ['fujii k', 1]
# ['urano n', 1]
# ['ushio h', 1]
# ['kimura s', 1]
# ['song b', 1]
# ['palleroni n j', 1]
# ['kerkhof l j', 1]
# ['mityushina l l', 1]
# ['robertson l a', 1]
# ['kuenen g j', 1]
# ['katsura k', 1]
# ['kawasaki h', 1]
# ['potacharoen w', 1]
# ['saono s', 1]
# ['seki t', 1]
# ['yamada y', 1]
# ['uchimura t', 1]
# ['de baere t', 1]
# ['steyaert s', 1]
# ['des vos p', 1]
# ['suyama t', 1]
# ['verschraegen g', 1]
# ['vaneechoutte m', 1]
# ['elo s', 1]
# ['suominen i', 1]
# ['juhanoja j', 1]
# ['salkinoja-salonen m', 1]
# ['haahtela k', 1]
# ['achenbach l a', 1]
# ['michaelidou u', 1]
# ['bruce r a', 1]
# ['fryman j', 1]
# ['coates j d', 1]
# ['derennes v', 1]
# ['godfroy a', 1]
# ['prowe s g', 1]
# ['fortina m g', 1]
# ['parini c', 1]
# ['novikova e v', 1]
# ['grigoryan a a', 1]
# ['ivanova a e', 1]
# ['petrunyaka v v', 1]
# ['belyaev s s', 1]
# ['ivanov m v', 1]
# ['farley j m', 1]
# ['zacher l a', 1]
# ['carlton j m', 1]
# ['clippinger t l', 1]
# ['talkington d f', 1]
# ['thacker w l', 1]
# ['dillehay d l', 1]
# ['kovacs g', 1]
# ['kovacs a l', 1]
# ['halbritter a', 2]
# ['descheemaeker p', 1]
# ['goossens h', 1]
# ['pot b', 1]
# ['cui x l', 1]
# ['mao p h', 1]
# ['zeng m', 1]
# ['li w j', 1]
# ['zhang l p', 1]
# ['xu l h', 1]
# ['jiang c l', 1]
# ['yamazaki k', 1]
# ['hishinuma m', 1]
# ['suemori a', 1]
# ['nakajima k', 1]
# ['inoue n', 1]
# ['kawasaki k', 1]
# ['surkov a v', 1]
# ['glockner f o', 1]
# ['kuever j', 2]
# ['cann i k', 1]
# ['stroot p g', 1]
# ['mackie k r', 1]
# ['white b a', 1]
# ['mackie r i', 1]
# ['yabuuchi e', 1]
# ['yamamoto h', 1]
# ['terakubo s', 1]
# ['okamura n', 1]
# ['naka t', 1]
# ['fujiwara n', 1]
# ['kobayashi k', 1]
# ['kosako y', 1]
# ['hiraishi a', 1]
# ['simpson k l', 1]
# ['priest f g', 1]
# ['kattar m m', 1]
# ['cookson b t', 1]
# ['carlson l d', 1]
# ['stiglich s k', 1]
# ['schwartz m a', 1]
# ['nguyen t t', 1]
# ['daza r', 1]
# ['wallis c k', 1]
# ['yarfitz s l', 1]
# ['coyle m b', 1]
# ['schuetze b', 1]
# ['augsten k', 1]
# ['schut f', 1]
# ['brown g r', 1]
# ['sutcliffe i c', 1]
# ['hedlund b p', 1]
# ['staley j t', 1]
# ['eriksson e', 1]
# ['papademas p', 1]
# ['wacher c', 1]
# ['robinson r', 1]
# ['kitahara m', 1]
# ['takamine f', 1]
# ['imamura t', 1]
# ['benno y', 1]
# ['kim s b', 1]
# ['minnikin d e', 1]
# ['whitehead d', 1]
# ['zhou z h', 1]
# ['mattinson-rose a d', 1]
# ['konneke m', 1]
# ['galushko a', 1]
# ['drzyzga o', 1]
# ['eckert b', 2]
# ['weber o b', 1]
# ['kirchhof g', 2]
# ['grainger j m', 1]
# ['kato c', 1]
# ['robb f t', 1]
# ['robertson w j', 1]
# ['bowman j p', 1]
# ['franzmann p d', 1]
# ['mee b j', 1]
# ['monserrate e', 1]
# ['leschine s b', 1]
# ['canale-parola e', 1]
# ['mcdonald i r', 1]
# ['mcanulla c', 1]
# ['murrell j c', 1]
# ['pfennig n', 1]
# ['engelhardt m a', 1]
# ['daly k', 1]
# ['swannell r p', 1]
# ['head i m', 1]

# %%
df_authors = pd.DataFrame.from_dict(frequency_authors, orient='index')

# %%
df_authors.columns = ["freq"]

# %%
df_authors.to_csv("authors_freq.txt")
